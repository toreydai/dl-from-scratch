# %% [markdown]
# ## batch_norm_gradient_check.py

# %%
# coding: utf-8
import sys, os
sys.path.append(os.pardir)  # 为了导入父目录的文件而进行的设定
import numpy as np
from dataset.mnist import load_mnist
from common.multi_layer_net_extend import MultiLayerNetExtend

# 读入数据
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True, one_hot_label=True)

network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100], output_size=10,
                              use_batchnorm=True)

x_batch = x_train[:1]
t_batch = t_train[:1]

grad_backprop = network.gradient(x_batch, t_batch)
grad_numerical = network.numerical_gradient(x_batch, t_batch)


for key in grad_numerical.keys():
    diff = np.average( np.abs(grad_backprop[key] - grad_numerical[key]) )
    print(key + ":" + str(diff))
# Out:
# W1:0.0
# b1:0.0
# gamma1:0.0
# beta1:0.0
# W2:0.0
# b2:0.0
# gamma2:0.0
# beta2:0.055658221452903334
# W3:0.0
# b3:1.7990402263745597e-07

# %% [markdown]
# ## batch_norm_test.py

# %%
# coding: utf-8
import sys, os
sys.path.append(os.pardir)  # 为了导入父目录的文件而进行的设定
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net_extend import MultiLayerNetExtend
from common.optimizer import SGD, Adam

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 减少学习数据
x_train = x_train[:1000]
t_train = t_train[:1000]

max_epochs = 20
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.01


def __train(weight_init_std):
    bn_network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100], output_size=10, 
                                    weight_init_std=weight_init_std, use_batchnorm=True)
    network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100], output_size=10,
                                weight_init_std=weight_init_std)
    optimizer = SGD(lr=learning_rate)
    
    train_acc_list = []
    bn_train_acc_list = []
    
    iter_per_epoch = max(train_size / batch_size, 1)
    epoch_cnt = 0
    
    for i in range(1000000000):
        batch_mask = np.random.choice(train_size, batch_size)
        x_batch = x_train[batch_mask]
        t_batch = t_train[batch_mask]
    
        for _network in (bn_network, network):
            grads = _network.gradient(x_batch, t_batch)
            optimizer.update(_network.params, grads)
    
        if i % iter_per_epoch == 0:
            train_acc = network.accuracy(x_train, t_train)
            bn_train_acc = bn_network.accuracy(x_train, t_train)
            train_acc_list.append(train_acc)
            bn_train_acc_list.append(bn_train_acc)
    
            print("epoch:" + str(epoch_cnt) + " | " + str(train_acc) + " - " + str(bn_train_acc))
    
            epoch_cnt += 1
            if epoch_cnt >= max_epochs:
                break
                
    return train_acc_list, bn_train_acc_list


# 3.绘制图形==========
weight_scale_list = np.logspace(0, -4, num=16)
x = np.arange(max_epochs)

plt.figure(figsize=(18,12), dpi= 80)

for i, w in enumerate(weight_scale_list):
    print( "============== " + str(i+1) + "/16" + " ==============")
    train_acc_list, bn_train_acc_list = __train(w)
       
    plt.subplot(4,4,i+1)
    plt.title("W:" + str(w))
    if i == 15:
        plt.plot(x, bn_train_acc_list, label='Batch Normalization', markevery=2)
        plt.plot(x, train_acc_list, linestyle = "--", label='Normal(without BatchNorm)', markevery=2)
    else:
        plt.plot(x, bn_train_acc_list, markevery=2)
        plt.plot(x, train_acc_list, linestyle="--", markevery=2)

    plt.ylim(0, 1.0)
    if i % 4:
        plt.yticks([])
    else:
        plt.ylabel("accuracy")
    if i < 12:
        plt.xticks([])
    else:
        plt.xlabel("epochs")
    plt.legend(loc='lower right')
    
plt.show()
# Out:
# ============== 1/16 ==============
# epoch:0 | 0.105 - 0.109
# /home/ec2-user/SageMaker/dl-from-scratch/common/functions.py:34: RuntimeWarning: invalid value encountered in subtract
#   x = x - np.max(x, axis=0)
# /home/ec2-user/SageMaker/dl-from-scratch/common/layers.py:12: RuntimeWarning: invalid value encountered in less_equal
#   self.mask = (x <= 0)
# epoch:1 | 0.097 - 0.13
# epoch:2 | 0.097 - 0.168
# epoch:3 | 0.097 - 0.203
# epoch:4 | 0.097 - 0.232
# epoch:5 | 0.097 - 0.254
# epoch:6 | 0.097 - 0.261
# epoch:7 | 0.097 - 0.273
# epoch:8 | 0.097 - 0.29
# epoch:9 | 0.097 - 0.3
# epoch:10 | 0.097 - 0.313
# epoch:11 | 0.097 - 0.334
# epoch:12 | 0.097 - 0.347
# epoch:13 | 0.097 - 0.369
# epoch:14 | 0.097 - 0.369
# epoch:15 | 0.097 - 0.384
# epoch:16 | 0.097 - 0.401
# epoch:17 | 0.097 - 0.411
# epoch:18 | 0.097 - 0.419
# No handles with labels found to put in legend.
# epoch:19 | 0.097 - 0.428
# ============== 2/16 ==============
# epoch:0 | 0.092 - 0.11
# epoch:1 | 0.097 - 0.098
# /home/ec2-user/SageMaker/dl-from-scratch/common/multi_layer_net_extend.py:101: RuntimeWarning: overflow encountered in square
#   weight_decay += 0.5 * self.weight_decay_lambda * np.sum(W**2)
# /home/ec2-user/SageMaker/dl-from-scratch/common/multi_layer_net_extend.py:101: RuntimeWarning: invalid value encountered in double_scalars
#   weight_decay += 0.5 * self.weight_decay_lambda * np.sum(W**2)
# epoch:2 | 0.097 - 0.131
# epoch:3 | 0.097 - 0.161
# epoch:4 | 0.097 - 0.188
# epoch:5 | 0.097 - 0.2
# epoch:6 | 0.097 - 0.235
# epoch:7 | 0.097 - 0.252
# epoch:8 | 0.097 - 0.276
# epoch:9 | 0.097 - 0.297
# epoch:10 | 0.097 - 0.315
# epoch:11 | 0.097 - 0.343
# epoch:12 | 0.097 - 0.363
# epoch:13 | 0.097 - 0.388
# epoch:14 | 0.097 - 0.394
# epoch:15 | 0.097 - 0.427
# epoch:16 | 0.097 - 0.44
# epoch:17 | 0.097 - 0.457
# No handles with labels found to put in legend.
# epoch:18 | 0.097 - 0.47
# epoch:19 | 0.097 - 0.489
# ============== 3/16 ==============
# epoch:0 | 0.133 - 0.086
# epoch:1 | 0.365 - 0.106
# epoch:2 | 0.533 - 0.126
# epoch:3 | 0.604 - 0.166
# epoch:4 | 0.674 - 0.189
# epoch:5 | 0.74 - 0.215
# epoch:6 | 0.781 - 0.256
# epoch:7 | 0.832 - 0.302
# epoch:8 | 0.869 - 0.344
# epoch:9 | 0.893 - 0.387
# epoch:10 | 0.908 - 0.411
# epoch:11 | 0.924 - 0.446
# epoch:12 | 0.944 - 0.479
# epoch:13 | 0.958 - 0.501
# epoch:14 | 0.964 - 0.533
# epoch:15 | 0.97 - 0.556
# epoch:16 | 0.978 - 0.574
# epoch:17 | 0.983 - 0.6
# epoch:18 | 0.987 - 0.616
# No handles with labels found to put in legend.
# epoch:19 | 0.988 - 0.633
# ============== 4/16 ==============
# epoch:0 | 0.097 - 0.122
# epoch:1 | 0.221 - 0.122
# epoch:2 | 0.399 - 0.176
# epoch:3 | 0.503 - 0.237
# epoch:4 | 0.566 - 0.291
# epoch:5 | 0.621 - 0.376
# epoch:6 | 0.664 - 0.453
# epoch:7 | 0.698 - 0.517
# epoch:8 | 0.721 - 0.566
# epoch:9 | 0.748 - 0.611
# epoch:10 | 0.769 - 0.638
# epoch:11 | 0.779 - 0.655
# epoch:12 | 0.795 - 0.683
# epoch:13 | 0.816 - 0.709
# epoch:14 | 0.836 - 0.731
# epoch:15 | 0.827 - 0.751
# epoch:16 | 0.844 - 0.766
# epoch:17 | 0.839 - 0.784
# No handles with labels found to put in legend.
# epoch:18 | 0.871 - 0.797
# epoch:19 | 0.873 - 0.814
# ============== 5/16 ==============
# epoch:0 | 0.114 - 0.066
# epoch:1 | 0.126 - 0.167
# epoch:2 | 0.13 - 0.349
# epoch:3 | 0.139 - 0.475
# epoch:4 | 0.149 - 0.554
# epoch:5 | 0.148 - 0.607
# epoch:6 | 0.149 - 0.658
# epoch:7 | 0.153 - 0.707
# epoch:8 | 0.146 - 0.739
# epoch:9 | 0.144 - 0.765
# epoch:10 | 0.145 - 0.785
# epoch:11 | 0.145 - 0.801
# epoch:12 | 0.144 - 0.823
# epoch:13 | 0.14 - 0.833
# epoch:14 | 0.142 - 0.842
# epoch:15 | 0.148 - 0.859
# epoch:16 | 0.161 - 0.87
# epoch:17 | 0.177 - 0.875
# epoch:18 | 0.181 - 0.884
# No handles with labels found to put in legend.
# epoch:19 | 0.185 - 0.891
# ============== 6/16 ==============
# epoch:0 | 0.104 - 0.121
# epoch:1 | 0.125 - 0.202
# epoch:2 | 0.11 - 0.434
# epoch:3 | 0.096 - 0.589
# epoch:4 | 0.1 - 0.666
# epoch:5 | 0.108 - 0.716
# epoch:6 | 0.116 - 0.747
# epoch:7 | 0.111 - 0.782
# epoch:8 | 0.115 - 0.803
# epoch:9 | 0.115 - 0.815
# epoch:10 | 0.116 - 0.833
# epoch:11 | 0.116 - 0.848
# epoch:12 | 0.116 - 0.864
# epoch:13 | 0.116 - 0.873
# epoch:14 | 0.116 - 0.875
# epoch:15 | 0.116 - 0.894
# epoch:16 | 0.119 - 0.905
# epoch:17 | 0.115 - 0.917
# No handles with labels found to put in legend.
# epoch:18 | 0.143 - 0.927
# epoch:19 | 0.127 - 0.93
# ============== 7/16 ==============
# epoch:0 | 0.101 - 0.082
# epoch:1 | 0.117 - 0.29
# epoch:2 | 0.138 - 0.518
# epoch:3 | 0.117 - 0.619
# epoch:4 | 0.118 - 0.673
# epoch:5 | 0.116 - 0.713
# epoch:6 | 0.116 - 0.754
# epoch:7 | 0.116 - 0.791
# epoch:8 | 0.116 - 0.823
# epoch:9 | 0.116 - 0.862
# epoch:10 | 0.116 - 0.889
# epoch:11 | 0.116 - 0.911
# epoch:12 | 0.116 - 0.932
# epoch:13 | 0.117 - 0.948
# epoch:14 | 0.117 - 0.961
# epoch:15 | 0.117 - 0.969
# epoch:16 | 0.117 - 0.972
# epoch:17 | 0.117 - 0.977
# epoch:18 | 0.117 - 0.981
# No handles with labels found to put in legend.
# epoch:19 | 0.117 - 0.983
# ============== 8/16 ==============
# epoch:0 | 0.117 - 0.083
# epoch:1 | 0.117 - 0.304
# epoch:2 | 0.117 - 0.662
# epoch:3 | 0.117 - 0.793
# epoch:4 | 0.117 - 0.818
# epoch:5 | 0.117 - 0.867
# epoch:6 | 0.117 - 0.898
# epoch:7 | 0.117 - 0.937
# epoch:8 | 0.117 - 0.959
# epoch:9 | 0.117 - 0.975
# epoch:10 | 0.117 - 0.981
# epoch:11 | 0.117 - 0.984
# epoch:12 | 0.117 - 0.99
# epoch:13 | 0.117 - 0.995
# epoch:14 | 0.117 - 0.995
# epoch:15 | 0.117 - 0.997
# epoch:16 | 0.117 - 0.997
# epoch:17 | 0.117 - 0.997
# No handles with labels found to put in legend.
# epoch:18 | 0.117 - 0.997
# epoch:19 | 0.117 - 0.998
# ============== 9/16 ==============
# epoch:0 | 0.105 - 0.153
# epoch:1 | 0.117 - 0.463
# epoch:2 | 0.117 - 0.735
# epoch:3 | 0.116 - 0.838
# epoch:4 | 0.116 - 0.885
# epoch:5 | 0.116 - 0.913
# epoch:6 | 0.116 - 0.949
# epoch:7 | 0.116 - 0.97
# epoch:8 | 0.116 - 0.981
# epoch:9 | 0.116 - 0.983
# epoch:10 | 0.117 - 0.99
# epoch:11 | 0.117 - 0.996
# epoch:12 | 0.117 - 0.998
# epoch:13 | 0.116 - 0.999
# epoch:14 | 0.117 - 1.0
# epoch:15 | 0.117 - 1.0
# epoch:16 | 0.116 - 1.0
# epoch:17 | 0.116 - 1.0
# epoch:18 | 0.116 - 1.0
# No handles with labels found to put in legend.
# epoch:19 | 0.116 - 1.0
# ============== 10/16 ==============
# epoch:0 | 0.094 - 0.115
# epoch:1 | 0.105 - 0.592
# epoch:2 | 0.117 - 0.794
# epoch:3 | 0.117 - 0.854
# epoch:4 | 0.116 - 0.887
# epoch:5 | 0.117 - 0.912
# epoch:6 | 0.117 - 0.89
# epoch:7 | 0.117 - 0.948
# epoch:8 | 0.117 - 0.979
# epoch:9 | 0.117 - 0.989
# epoch:10 | 0.117 - 0.99
# epoch:11 | 0.117 - 0.95
# epoch:12 | 0.117 - 0.992
# epoch:13 | 0.117 - 0.991
# epoch:14 | 0.117 - 0.992
# epoch:15 | 0.117 - 0.893
# epoch:16 | 0.117 - 0.993
# epoch:17 | 0.117 - 0.996
# No handles with labels found to put in legend.
# epoch:18 | 0.117 - 0.996
# epoch:19 | 0.117 - 0.996
# ============== 11/16 ==============
# epoch:0 | 0.094 - 0.115
# epoch:1 | 0.105 - 0.529
# epoch:2 | 0.116 - 0.695
# epoch:3 | 0.117 - 0.729
# epoch:4 | 0.117 - 0.752
# epoch:5 | 0.117 - 0.768
# epoch:6 | 0.117 - 0.759
# epoch:7 | 0.117 - 0.767
# epoch:8 | 0.117 - 0.793
# epoch:9 | 0.117 - 0.808
# epoch:10 | 0.117 - 0.81
# epoch:11 | 0.117 - 0.891
# epoch:12 | 0.117 - 0.899
# epoch:13 | 0.117 - 0.898
# epoch:14 | 0.117 - 0.903
# epoch:15 | 0.117 - 0.9
# epoch:16 | 0.117 - 0.903
# epoch:17 | 0.117 - 0.859
# epoch:18 | 0.117 - 0.903
# No handles with labels found to put in legend.
# epoch:19 | 0.117 - 0.891
# ============== 12/16 ==============
# epoch:0 | 0.105 - 0.25
# epoch:1 | 0.116 - 0.328
# epoch:2 | 0.116 - 0.513
# epoch:3 | 0.116 - 0.603
# epoch:4 | 0.116 - 0.702
# epoch:5 | 0.116 - 0.759
# epoch:6 | 0.116 - 0.784
# epoch:7 | 0.116 - 0.753
# epoch:8 | 0.116 - 0.787
# epoch:9 | 0.116 - 0.8
# epoch:10 | 0.116 - 0.778
# epoch:11 | 0.116 - 0.798
# epoch:12 | 0.116 - 0.783
# epoch:13 | 0.116 - 0.803
# epoch:14 | 0.116 - 0.78
# epoch:15 | 0.116 - 0.809
# epoch:16 | 0.116 - 0.813
# epoch:17 | 0.116 - 0.812
# epoch:18 | 0.116 - 0.813
# No handles with labels found to put in legend.
# epoch:19 | 0.116 - 0.806
# ============== 13/16 ==============
# epoch:0 | 0.087 - 0.17
# epoch:1 | 0.117 - 0.393
# epoch:2 | 0.117 - 0.642
# epoch:3 | 0.117 - 0.613
# epoch:4 | 0.117 - 0.741
# epoch:5 | 0.117 - 0.777
# epoch:6 | 0.117 - 0.765
# epoch:7 | 0.117 - 0.775
# epoch:8 | 0.117 - 0.808
# epoch:9 | 0.117 - 0.829
# epoch:10 | 0.117 - 0.862
# epoch:11 | 0.117 - 0.86
# epoch:12 | 0.117 - 0.863
# epoch:13 | 0.117 - 0.875
# epoch:14 | 0.117 - 0.877
# epoch:15 | 0.117 - 0.889
# epoch:16 | 0.117 - 0.889
# epoch:17 | 0.117 - 0.889
# epoch:18 | 0.117 - 0.889
# No handles with labels found to put in legend.
# epoch:19 | 0.117 - 0.892
# ============== 14/16 ==============
# epoch:0 | 0.116 - 0.202
# epoch:1 | 0.116 - 0.305
# epoch:2 | 0.117 - 0.393
# epoch:3 | 0.117 - 0.413
# epoch:4 | 0.117 - 0.41
# epoch:5 | 0.116 - 0.421
# epoch:6 | 0.117 - 0.399
# epoch:7 | 0.117 - 0.424
# epoch:8 | 0.117 - 0.431
# epoch:9 | 0.117 - 0.431
# epoch:10 | 0.117 - 0.428
# epoch:11 | 0.117 - 0.431
# epoch:12 | 0.117 - 0.428
# epoch:13 | 0.117 - 0.431
# epoch:14 | 0.117 - 0.43
# epoch:15 | 0.117 - 0.431
# epoch:16 | 0.117 - 0.435
# epoch:17 | 0.117 - 0.435
# No handles with labels found to put in legend.
# epoch:18 | 0.117 - 0.437
# epoch:19 | 0.117 - 0.443
# ============== 15/16 ==============
# epoch:0 | 0.117 - 0.127
# epoch:1 | 0.116 - 0.283
# epoch:2 | 0.116 - 0.553
# epoch:3 | 0.116 - 0.556
# epoch:4 | 0.116 - 0.594
# epoch:5 | 0.116 - 0.556
# epoch:6 | 0.116 - 0.603
# epoch:7 | 0.116 - 0.606
# epoch:8 | 0.117 - 0.594
# epoch:9 | 0.117 - 0.615
# epoch:10 | 0.117 - 0.613
# epoch:11 | 0.117 - 0.611
# epoch:12 | 0.117 - 0.618
# epoch:13 | 0.117 - 0.622
# epoch:14 | 0.117 - 0.62
# epoch:15 | 0.117 - 0.623
# epoch:16 | 0.117 - 0.62
# epoch:17 | 0.117 - 0.623
# epoch:18 | 0.117 - 0.69
# No handles with labels found to put in legend.
# epoch:19 | 0.117 - 0.655
# ============== 16/16 ==============
# epoch:0 | 0.094 - 0.106
# epoch:1 | 0.117 - 0.318
# epoch:2 | 0.117 - 0.361
# epoch:3 | 0.117 - 0.399
# epoch:4 | 0.117 - 0.405
# epoch:5 | 0.117 - 0.417
# epoch:6 | 0.117 - 0.421
# epoch:7 | 0.117 - 0.421
# epoch:8 | 0.117 - 0.423
# epoch:9 | 0.117 - 0.425
# epoch:10 | 0.117 - 0.426
# epoch:11 | 0.117 - 0.482
# epoch:12 | 0.117 - 0.509
# epoch:13 | 0.117 - 0.476
# epoch:14 | 0.117 - 0.509
# epoch:15 | 0.116 - 0.521
# epoch:16 | 0.116 - 0.52
# epoch:17 | 0.116 - 0.521
# epoch:18 | 0.116 - 0.511
# epoch:19 | 0.117 - 0.525

# %% [markdown]
# ## hyperparameter_optimization.py

# %%
# coding: utf-8
import sys, os
sys.path.append(os.pardir)  # 为了导入父目录的文件而进行的设定
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.util import shuffle_dataset
from common.trainer import Trainer

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 为了实现高速化，减少训练数据
x_train = x_train[:500]
t_train = t_train[:500]

# 分割验证数据
validation_rate = 0.20
validation_num = int(x_train.shape[0] * validation_rate)
x_train, t_train = shuffle_dataset(x_train, t_train)
x_val = x_train[:validation_num]
t_val = t_train[:validation_num]
x_train = x_train[validation_num:]
t_train = t_train[validation_num:]


def __train(lr, weight_decay, epocs=50):
    network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100],
                            output_size=10, weight_decay_lambda=weight_decay)
    trainer = Trainer(network, x_train, t_train, x_val, t_val,
                      epochs=epocs, mini_batch_size=100,
                      optimizer='sgd', optimizer_param={'lr': lr}, verbose=False)
    trainer.train()

    return trainer.test_acc_list, trainer.train_acc_list


# 超参数的随机搜索======================================
optimization_trial = 100
results_val = {}
results_train = {}
for _ in range(optimization_trial):
    # 指定搜索的超参数的范围===============
    weight_decay = 10 ** np.random.uniform(-8, -4)
    lr = 10 ** np.random.uniform(-6, -2)
    # ================================================

    val_acc_list, train_acc_list = __train(lr, weight_decay)
    print("val acc:" + str(val_acc_list[-1]) + " | lr:" + str(lr) + ", weight decay:" + str(weight_decay))
    key = "lr:" + str(lr) + ", weight decay:" + str(weight_decay)
    results_val[key] = val_acc_list
    results_train[key] = train_acc_list

# 绘制图形========================================================
print("=========== Hyper-Parameter Optimization Result ===========")
graph_draw_num = 20
col_num = 5
row_num = int(np.ceil(graph_draw_num / col_num))
i = 0

plt.figure(figsize=(12,10), dpi= 80)

for key, val_acc_list in sorted(results_val.items(), key=lambda x:x[1][-1], reverse=True):
    print("Best-" + str(i+1) + "(val acc:" + str(val_acc_list[-1]) + ") | " + key)

    plt.subplot(row_num, col_num, i+1)
    plt.title("Best-" + str(i+1))
    plt.ylim(0.0, 1.0)
    if i % 5: plt.yticks([])
    plt.xticks([])
    x = np.arange(len(val_acc_list))
    plt.plot(x, val_acc_list)
    plt.plot(x, results_train[key], "--")
    i += 1

    if i >= graph_draw_num:
        break

plt.show()
# Out:
# val acc:0.07 | lr:9.225207931027262e-05, weight decay:2.587873849902529e-07
# val acc:0.1 | lr:0.00022895662181566343, weight decay:6.885274973934821e-05
# val acc:0.09 | lr:0.00022170469171550094, weight decay:2.5161303156406417e-05
# val acc:0.09 | lr:0.00040073753753130904, weight decay:1.2605086003589035e-05
# val acc:0.1 | lr:0.00042172255390001957, weight decay:9.210859705249363e-07
# val acc:0.12 | lr:1.5645977207589146e-06, weight decay:3.14480756070474e-05
# val acc:0.1 | lr:4.752136291614387e-05, weight decay:1.273521009261811e-07
# val acc:0.06 | lr:1.826770380087759e-06, weight decay:1.0240536846054839e-05
# val acc:0.11 | lr:0.00014367086623745862, weight decay:9.615808522162521e-08
# val acc:0.15 | lr:0.0007955412396545695, weight decay:4.9455002557401414e-05
# val acc:0.76 | lr:0.007183320822230943, weight decay:2.0198471325038436e-06
# val acc:0.15 | lr:1.0913732152824489e-05, weight decay:2.2601210693958632e-06
# val acc:0.14 | lr:1.7356031747836915e-05, weight decay:6.315359468834837e-07
# val acc:0.12 | lr:5.939827455913679e-06, weight decay:8.426400982624133e-05
# val acc:0.11 | lr:1.254796512445814e-06, weight decay:2.199183634702159e-08
# val acc:0.04 | lr:7.203103237187468e-06, weight decay:3.3218347545100267e-06
# val acc:0.08 | lr:0.00021196918634836122, weight decay:4.556530516565282e-06
# val acc:0.08 | lr:2.229098087400305e-06, weight decay:8.281113337492995e-06
# val acc:0.25 | lr:0.0014780951213130369, weight decay:1.1315184692800956e-05
# val acc:0.46 | lr:0.003908049204717228, weight decay:2.2246287457938116e-06
# val acc:0.06 | lr:2.062302381403785e-06, weight decay:7.563462782249001e-05
# val acc:0.72 | lr:0.006642581270934167, weight decay:3.1942140531965626e-07
# val acc:0.68 | lr:0.005588626616449564, weight decay:7.970886970668742e-05
# val acc:0.16 | lr:8.323639432216313e-06, weight decay:8.275807959987096e-07
# val acc:0.79 | lr:0.009996800322370335, weight decay:1.3036171177792178e-07
# val acc:0.1 | lr:0.0008913154905346965, weight decay:8.871128018757988e-07
# val acc:0.09 | lr:8.493827279912682e-06, weight decay:6.080954324998173e-07
# val acc:0.11 | lr:0.0003608351093861589, weight decay:8.210228404844413e-08
# val acc:0.06 | lr:7.90455321695276e-06, weight decay:1.66688318824373e-08
# val acc:0.17 | lr:0.0001403824230363231, weight decay:2.935802283743887e-05
# val acc:0.1 | lr:1.3392129208633825e-05, weight decay:1.0264337808728317e-07
# val acc:0.41 | lr:0.004070774175335761, weight decay:2.0635245339322186e-05
# val acc:0.08 | lr:1.2131833049516238e-06, weight decay:1.8821486752495914e-06
# val acc:0.05 | lr:2.9016467713104806e-05, weight decay:1.911509413199719e-08
# val acc:0.62 | lr:0.004924427969544659, weight decay:4.8165534467183486e-05
# val acc:0.47 | lr:0.002842041613253035, weight decay:1.6852753256206836e-08
# val acc:0.11 | lr:0.0003842367197076564, weight decay:2.8921796665900643e-08
# val acc:0.39 | lr:0.004616708160645592, weight decay:6.297963268058833e-08
# val acc:0.07 | lr:9.80678578473801e-05, weight decay:9.956149381235576e-07
# val acc:0.14 | lr:0.0001968044493113662, weight decay:6.351675581419787e-05
# val acc:0.1 | lr:0.00012671578157823798, weight decay:2.1192608048373485e-05
# val acc:0.28 | lr:0.0023251799123281294, weight decay:5.579559638685602e-07
# val acc:0.05 | lr:5.5558605709596455e-06, weight decay:2.3160313054879705e-08
# val acc:0.13 | lr:3.958978626113684e-05, weight decay:4.551800447740047e-06
# val acc:0.05 | lr:0.0002380175353587565, weight decay:2.3723758105762983e-07
# val acc:0.21 | lr:0.0002736636980265921, weight decay:2.836286519987676e-06
# val acc:0.66 | lr:0.0072221418317454395, weight decay:2.3021261023672773e-06
# val acc:0.04 | lr:2.0273742330881525e-05, weight decay:3.0394657718931953e-06
# val acc:0.18 | lr:0.0004361273325358666, weight decay:5.614115172683804e-06
# val acc:0.09 | lr:1.3676164397694879e-05, weight decay:6.219256659720629e-05
# val acc:0.19 | lr:0.0009353059726243205, weight decay:1.8724081815259797e-07
# val acc:0.14 | lr:5.752297611465724e-06, weight decay:4.085871828245215e-07
# val acc:0.1 | lr:0.0004091186698201226, weight decay:4.9285339242667554e-08
# val acc:0.08 | lr:1.6089182565884968e-06, weight decay:5.317779213511681e-05
# val acc:0.12 | lr:0.0004058070193025742, weight decay:2.195678194882047e-05
# val acc:0.12 | lr:2.470591865242405e-05, weight decay:1.0213355491644517e-08
# val acc:0.23 | lr:0.0008803212560616714, weight decay:1.8268117835786493e-08
# val acc:0.38 | lr:0.0031072402020402884, weight decay:1.3397526603096789e-05
# val acc:0.04 | lr:3.156827466365997e-06, weight decay:4.095308986356985e-06
# val acc:0.09 | lr:0.00024278005944828855, weight decay:9.801084418131878e-05
# val acc:0.06 | lr:1.721006162196749e-05, weight decay:1.73764422740163e-07
# val acc:0.27 | lr:0.0019149991553356297, weight decay:4.3674968881110225e-05
# val acc:0.14 | lr:0.0001069765126767539, weight decay:7.438380885638512e-08
# val acc:0.13 | lr:0.0015239256691434028, weight decay:7.052321177513735e-05
# val acc:0.1 | lr:0.0003515029531468251, weight decay:2.545137764266008e-06
# val acc:0.12 | lr:4.982988402743798e-06, weight decay:3.261773971805158e-08
# val acc:0.08 | lr:2.5082280966989536e-06, weight decay:6.379465974606221e-07
# val acc:0.68 | lr:0.006099503217447703, weight decay:2.4983546416219506e-05
# val acc:0.11 | lr:6.427918352779498e-05, weight decay:6.063302303696585e-05
# val acc:0.11 | lr:8.959311003671786e-05, weight decay:4.807693556130935e-08
# val acc:0.68 | lr:0.005787136822634187, weight decay:1.237365574012846e-08
# val acc:0.73 | lr:0.0077881469529186495, weight decay:3.016661810189717e-06
# val acc:0.12 | lr:0.00023476797743985178, weight decay:4.790156107453111e-06
# val acc:0.1 | lr:1.8601757796624486e-05, weight decay:1.2955210539012133e-07
# val acc:0.06 | lr:8.994833030285586e-06, weight decay:9.965301346599831e-06
# val acc:0.82 | lr:0.009948593715844787, weight decay:6.87406439960317e-05
# val acc:0.08 | lr:1.5250827453813673e-06, weight decay:4.9612205139490925e-08
# val acc:0.24 | lr:0.0008195058000669104, weight decay:2.4186597999467406e-08
# val acc:0.55 | lr:0.0031827048858503026, weight decay:2.666970762797493e-07
# val acc:0.09 | lr:1.3388238347711526e-06, weight decay:1.8809155574297906e-05
# val acc:0.15 | lr:9.150859619756942e-06, weight decay:6.217787280862914e-07
# val acc:0.1 | lr:0.00026222736619181507, weight decay:4.2844949944070646e-07
# val acc:0.07 | lr:2.2871536594277477e-05, weight decay:4.252646654216834e-05
# val acc:0.09 | lr:1.3581307195229957e-06, weight decay:7.141785996066467e-08
# val acc:0.13 | lr:6.229555466418585e-05, weight decay:3.690341844481324e-07
# val acc:0.76 | lr:0.006156737982971437, weight decay:1.839157414378712e-08
# val acc:0.05 | lr:1.9436993667371118e-05, weight decay:4.4365285864226916e-07
# val acc:0.23 | lr:0.0013364989192537144, weight decay:7.626825904922847e-07
# val acc:0.81 | lr:0.006548480235349339, weight decay:8.750821490713028e-07
# val acc:0.07 | lr:3.212797201529461e-06, weight decay:5.618442534269347e-07
# val acc:0.16 | lr:4.601186770085778e-06, weight decay:1.3075417997954632e-05
# val acc:0.07 | lr:0.0002047506277643653, weight decay:1.6121164009907465e-08
# val acc:0.14 | lr:5.8189190270630036e-05, weight decay:2.243796176292249e-05
# val acc:0.49 | lr:0.002865149795906556, weight decay:1.7815706544314492e-07
# val acc:0.06 | lr:1.2216409106076507e-06, weight decay:8.206723543287787e-07
# val acc:0.11 | lr:0.000158884240520948, weight decay:5.867787841833404e-08
# val acc:0.04 | lr:8.918373785793407e-05, weight decay:2.4651596501382514e-05
# val acc:0.11 | lr:0.00012707894301205384, weight decay:3.442899899501719e-06
# val acc:0.12 | lr:5.049562679929472e-06, weight decay:5.517474889376511e-07
# val acc:0.08 | lr:1.3652559092282672e-05, weight decay:7.342369536208698e-05
# =========== Hyper-Parameter Optimization Result ===========
# Best-1(val acc:0.82) | lr:0.009948593715844787, weight decay:6.87406439960317e-05
# Best-2(val acc:0.81) | lr:0.006548480235349339, weight decay:8.750821490713028e-07
# Best-3(val acc:0.79) | lr:0.009996800322370335, weight decay:1.3036171177792178e-07
# Best-4(val acc:0.76) | lr:0.007183320822230943, weight decay:2.0198471325038436e-06
# Best-5(val acc:0.76) | lr:0.006156737982971437, weight decay:1.839157414378712e-08
# Best-6(val acc:0.73) | lr:0.0077881469529186495, weight decay:3.016661810189717e-06
# Best-7(val acc:0.72) | lr:0.006642581270934167, weight decay:3.1942140531965626e-07
# Best-8(val acc:0.68) | lr:0.005588626616449564, weight decay:7.970886970668742e-05
# Best-9(val acc:0.68) | lr:0.006099503217447703, weight decay:2.4983546416219506e-05
# Best-10(val acc:0.68) | lr:0.005787136822634187, weight decay:1.237365574012846e-08
# Best-11(val acc:0.66) | lr:0.0072221418317454395, weight decay:2.3021261023672773e-06
# Best-12(val acc:0.62) | lr:0.004924427969544659, weight decay:4.8165534467183486e-05
# Best-13(val acc:0.55) | lr:0.0031827048858503026, weight decay:2.666970762797493e-07
# Best-14(val acc:0.49) | lr:0.002865149795906556, weight decay:1.7815706544314492e-07
# Best-15(val acc:0.47) | lr:0.002842041613253035, weight decay:1.6852753256206836e-08
# Best-16(val acc:0.46) | lr:0.003908049204717228, weight decay:2.2246287457938116e-06
# Best-17(val acc:0.41) | lr:0.004070774175335761, weight decay:2.0635245339322186e-05
# Best-18(val acc:0.39) | lr:0.004616708160645592, weight decay:6.297963268058833e-08
# Best-19(val acc:0.38) | lr:0.0031072402020402884, weight decay:1.3397526603096789e-05
# Best-20(val acc:0.28) | lr:0.0023251799123281294, weight decay:5.579559638685602e-07

# %% [markdown]
# ## optimizer_compare_mnist.py

# %%
# coding: utf-8
import os
import sys
sys.path.append(os.pardir)  # 为了导入父目录的文件而进行的设定
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.util import smooth_curve
from common.multi_layer_net import MultiLayerNet
from common.optimizer import *


# 0:读入MNIST数据==========
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

train_size = x_train.shape[0]
batch_size = 128
max_iterations = 2000


# 1:进行实验的设置==========
optimizers = {}
optimizers['SGD'] = SGD()
optimizers['Momentum'] = Momentum()
optimizers['AdaGrad'] = AdaGrad()
optimizers['Adam'] = Adam()
#optimizers['RMSprop'] = RMSprop()

networks = {}
train_loss = {}
for key in optimizers.keys():
    networks[key] = MultiLayerNet(
        input_size=784, hidden_size_list=[100, 100, 100, 100],
        output_size=10)
    train_loss[key] = []    


# 2:开始训练==========
for i in range(max_iterations):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]
    
    for key in optimizers.keys():
        grads = networks[key].gradient(x_batch, t_batch)
        optimizers[key].update(networks[key].params, grads)
    
        loss = networks[key].loss(x_batch, t_batch)
        train_loss[key].append(loss)
    
    if i % 100 == 0:
        print( "===========" + "iteration:" + str(i) + "===========")
        for key in optimizers.keys():
            loss = networks[key].loss(x_batch, t_batch)
            print(key + ":" + str(loss))


# 3.绘制图形==========
markers = {"SGD": "o", "Momentum": "x", "AdaGrad": "s", "Adam": "D"}

plt.figure(figsize=(10,8), dpi= 80)

x = np.arange(max_iterations)
for key in optimizers.keys():
    plt.plot(x, smooth_curve(train_loss[key]), marker=markers[key], markevery=100, label=key)
plt.xlabel("iterations")
plt.ylabel("loss")
plt.ylim(0, 1)
plt.legend()
plt.show()
# Out:
# ===========iteration:0===========
# SGD:2.3698695240358214
# Momentum:2.334863254278422
# AdaGrad:2.2628367437126498
# Adam:2.295896344937281
# ===========iteration:100===========
# SGD:1.4605651761484484
# Momentum:0.2736667047300857
# AdaGrad:0.14609526292931097
# Adam:0.21958207459259468
# ===========iteration:200===========
# SGD:0.7436286214890504
# Momentum:0.21825577551968978
# AdaGrad:0.11065967560113217
# Adam:0.17979802381077714
# ===========iteration:300===========
# SGD:0.6233149402884068
# Momentum:0.24265668380518918
# AdaGrad:0.12940199274997832
# Adam:0.25028377241049304
# ===========iteration:400===========
# SGD:0.41772866999099806
# Momentum:0.16764905441370492
# AdaGrad:0.05550440899381667
# Adam:0.12373879924827626
# ===========iteration:500===========
# SGD:0.33075313799234674
# Momentum:0.10768141268878703
# AdaGrad:0.04404282106996391
# Adam:0.10025405286784049
# ===========iteration:600===========
# SGD:0.3429948523089734
# Momentum:0.14105792944406112
# AdaGrad:0.056455359335459226
# Adam:0.07600587222060133
# ===========iteration:700===========
# SGD:0.34745588160485896
# Momentum:0.19273435388327245
# AdaGrad:0.07095536094548796
# Adam:0.16275012315328571
# ===========iteration:800===========
# SGD:0.2521941168885594
# Momentum:0.0701601428491894
# AdaGrad:0.022102737590554505
# Adam:0.043326595205456384
# ===========iteration:900===========
# SGD:0.25291047783329074
# Momentum:0.11102328769962654
# AdaGrad:0.04489885768775266
# Adam:0.03672682206654954
# ===========iteration:1000===========
# SGD:0.3101849308309518
# Momentum:0.12500423648607328
# AdaGrad:0.07010756474560005
# Adam:0.0671557065024776
# ===========iteration:1100===========
# SGD:0.33947599628852143
# Momentum:0.11767932002558462
# AdaGrad:0.02898225002558105
# Adam:0.05825669045883778
# ===========iteration:1200===========
# SGD:0.19633906059216338
# Momentum:0.07179348780205508
# AdaGrad:0.02314506154967579
# Adam:0.019812217698519662
# ===========iteration:1300===========
# SGD:0.16252609571258222
# Momentum:0.04838023502461348
# AdaGrad:0.022281532943512303
# Adam:0.043136211688613306
# ===========iteration:1400===========
# SGD:0.24640480146578203
# Momentum:0.10947951116004256
# AdaGrad:0.04223966140045583
# Adam:0.05893491063830643
# ===========iteration:1500===========
# SGD:0.29822698332945646
# Momentum:0.09429223375175136
# AdaGrad:0.0398128358111201
# Adam:0.042629366494622414
# ===========iteration:1600===========
# SGD:0.23646591597893973
# Momentum:0.10058259400433148
# AdaGrad:0.05313978744197561
# Adam:0.08498387603953601
# ===========iteration:1700===========
# SGD:0.20264917489905404
# Momentum:0.07546040406116454
# AdaGrad:0.025198037199008448
# Adam:0.0528125335843269
# ===========iteration:1800===========
# SGD:0.20481299977802184
# Momentum:0.07740594913925625
# AdaGrad:0.01543210052077678
# Adam:0.041838065151416026
# ===========iteration:1900===========
# SGD:0.27073104335051623
# Momentum:0.1044429773408957
# AdaGrad:0.03469485912667694
# Adam:0.07410800367259801

# %% [markdown]
# ## optimizer_compare_naive.py

# %%
# coding: utf-8
import sys, os
sys.path.append(os.pardir)  # 为了导入父目录的文件而进行的设定
import numpy as np
import matplotlib.pyplot as plt
from collections import OrderedDict
from common.optimizer import *


def f(x, y):
    return x**2 / 20.0 + y**2


def df(x, y):
    return x / 10.0, 2.0*y

init_pos = (-7.0, 2.0)
params = {}
params['x'], params['y'] = init_pos[0], init_pos[1]
grads = {}
grads['x'], grads['y'] = 0, 0


optimizers = OrderedDict()
optimizers["SGD"] = SGD(lr=0.95)
optimizers["Momentum"] = Momentum(lr=0.1)
optimizers["AdaGrad"] = AdaGrad(lr=1.5)
optimizers["Adam"] = Adam(lr=0.3)

idx = 1

plt.figure(figsize=(15,12), dpi= 80)

for key in optimizers:
    optimizer = optimizers[key]
    x_history = []
    y_history = []
    params['x'], params['y'] = init_pos[0], init_pos[1]
    
    for i in range(30):
        x_history.append(params['x'])
        y_history.append(params['y'])
        
        grads['x'], grads['y'] = df(params['x'], params['y'])
        optimizer.update(params, grads)
    

    x = np.arange(-10, 10, 0.01)
    y = np.arange(-5, 5, 0.01)
    
    X, Y = np.meshgrid(x, y) 
    Z = f(X, Y)
    
    # for simple contour line  
    mask = Z > 7
    Z[mask] = 0
    
    # plot 
    plt.subplot(2, 2, idx)
    idx += 1
    plt.plot(x_history, y_history, 'o-', color="red")
    plt.contour(X, Y, Z)
    plt.ylim(-10, 10)
    plt.xlim(-10, 10)
    plt.plot(0, 0, '+')
    #colorbar()
    #spring()
    plt.title(key)
    plt.xlabel("x")
    plt.ylabel("y")
    
plt.show()

# %% [markdown]
# ## overfit_dropout.py

# %%
# coding: utf-8
import os
import sys
sys.path.append(os.pardir)  # 为了导入父目录的文件而进行的设定
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net_extend import MultiLayerNetExtend
from common.trainer import Trainer

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 为了再现过拟合，减少学习数据
x_train = x_train[:300]
t_train = t_train[:300]

# 设定是否使用Dropuout，以及比例 ========================
use_dropout = True  # 不使用Dropout的情况下为False
dropout_ratio = 0.2
# ====================================================

network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100],
                              output_size=10, use_dropout=use_dropout, dropout_ration=dropout_ratio)
trainer = Trainer(network, x_train, t_train, x_test, t_test,
                  epochs=301, mini_batch_size=100,
                  optimizer='sgd', optimizer_param={'lr': 0.01}, verbose=True)
trainer.train()

train_acc_list, test_acc_list = trainer.train_acc_list, trainer.test_acc_list

# 绘制图形==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(len(train_acc_list))
plt.figure(figsize=(12,10), dpi= 80)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# train loss:2.2910503782501848
# === epoch:1, train acc:0.09, test acc:0.0977 ===
# train loss:2.2875252693154895
# train loss:2.3042265943511318
# train loss:2.293639737130134
# === epoch:2, train acc:0.08333333333333333, test acc:0.0942 ===
# train loss:2.293919161307296
# train loss:2.293800999177712
# train loss:2.2893225147548564
# === epoch:3, train acc:0.09, test acc:0.0967 ===
# train loss:2.2898712825881207
# train loss:2.288615423713288
# train loss:2.2821580480219597
# === epoch:4, train acc:0.09333333333333334, test acc:0.102 ===
# train loss:2.295664564132676
# train loss:2.310887360023785
# train loss:2.292010036856283
# === epoch:5, train acc:0.09333333333333334, test acc:0.1035 ===
# train loss:2.2894915238799753
# train loss:2.2639024692974936
# train loss:2.2856063402745854
# === epoch:6, train acc:0.09666666666666666, test acc:0.1053 ===
# train loss:2.275104613510204
# train loss:2.2759419149297653
# train loss:2.290200084433962
# === epoch:7, train acc:0.09666666666666666, test acc:0.1074 ===
# train loss:2.2671864749411883
# train loss:2.2936299234353172
# train loss:2.2776298545341573
# === epoch:8, train acc:0.09666666666666666, test acc:0.1102 ===
# train loss:2.2762123884964516
# train loss:2.3040011115979775
# train loss:2.2822552013248445
# === epoch:9, train acc:0.10333333333333333, test acc:0.1127 ===
# train loss:2.291339285623636
# train loss:2.2758958526154087
# train loss:2.2830038393269154
# === epoch:10, train acc:0.09, test acc:0.1133 ===
# train loss:2.2885886438177985
# train loss:2.2861205230174995
# train loss:2.2678078893719356
# === epoch:11, train acc:0.09333333333333334, test acc:0.116 ===
# train loss:2.2679982309469224
# train loss:2.274299996946375
# train loss:2.2616453974480657
# === epoch:12, train acc:0.10333333333333333, test acc:0.1187 ===
# train loss:2.2688220554283847
# train loss:2.2705721614297945
# train loss:2.28272720949729
# === epoch:13, train acc:0.11, test acc:0.1233 ===
# train loss:2.2739676490711305
# train loss:2.2691331605068816
# train loss:2.275263638929283
# === epoch:14, train acc:0.11666666666666667, test acc:0.1278 ===
# train loss:2.272218531491478
# train loss:2.2759108918828543
# train loss:2.282620782058016
# === epoch:15, train acc:0.11666666666666667, test acc:0.128 ===
# train loss:2.2815554555025437
# train loss:2.2791537010116305
# train loss:2.256875337814554
# === epoch:16, train acc:0.12, test acc:0.1313 ===
# train loss:2.2696832820217168
# train loss:2.267604654614356
# train loss:2.2925802843870042
# === epoch:17, train acc:0.13333333333333333, test acc:0.1338 ===
# train loss:2.2763913652547076
# train loss:2.2643120364296747
# train loss:2.2574486962917923
# === epoch:18, train acc:0.14, test acc:0.1415 ===
# train loss:2.273606138242422
# train loss:2.26514788181438
# train loss:2.270389641214476
# === epoch:19, train acc:0.13666666666666666, test acc:0.1429 ===
# train loss:2.2690464233236027
# train loss:2.284793181629322
# train loss:2.282572021216958
# === epoch:20, train acc:0.13666666666666666, test acc:0.149 ===
# train loss:2.270118545651039
# train loss:2.2755667690708954
# train loss:2.253155902904329
# === epoch:21, train acc:0.13666666666666666, test acc:0.1535 ===
# train loss:2.256371501362047
# train loss:2.288325509714726
# train loss:2.2593109228959256
# === epoch:22, train acc:0.14666666666666667, test acc:0.1552 ===
# train loss:2.256822871160168
# train loss:2.2757208037271273
# train loss:2.2574926381319385
# === epoch:23, train acc:0.15666666666666668, test acc:0.1602 ===
# train loss:2.27904451766201
# train loss:2.264852192984605
# train loss:2.275366374009894
# === epoch:24, train acc:0.17, test acc:0.1702 ===
# train loss:2.2524989814509606
# train loss:2.270687135669537
# train loss:2.2612504864820715
# === epoch:25, train acc:0.17333333333333334, test acc:0.1772 ===
# train loss:2.260732188084919
# train loss:2.267027347670721
# train loss:2.267474968532086
# === epoch:26, train acc:0.17333333333333334, test acc:0.1795 ===
# train loss:2.2619564217015253
# train loss:2.262183792077461
# train loss:2.2613891203131056
# === epoch:27, train acc:0.18333333333333332, test acc:0.186 ===
# train loss:2.2750991362835022
# train loss:2.2603867220411833
# train loss:2.252313505796778
# === epoch:28, train acc:0.20333333333333334, test acc:0.193 ===
# train loss:2.2703441986022956
# train loss:2.256124347192643
# train loss:2.266990124765581
# === epoch:29, train acc:0.21, test acc:0.1975 ===
# train loss:2.24438915214792
# train loss:2.2651717203558253
# train loss:2.2936314588997213
# === epoch:30, train acc:0.21333333333333335, test acc:0.2009 ===
# train loss:2.2574740699306997
# train loss:2.265294203833544
# train loss:2.249994500348249
# === epoch:31, train acc:0.21666666666666667, test acc:0.2052 ===
# train loss:2.268823244843433
# train loss:2.2420599169047843
# train loss:2.2368474911338527
# === epoch:32, train acc:0.22666666666666666, test acc:0.2109 ===
# train loss:2.2584784688763384
# train loss:2.245080468693056
# train loss:2.262145265096324
# === epoch:33, train acc:0.22666666666666666, test acc:0.2143 ===
# train loss:2.2489102954776876
# train loss:2.2683155292782793
# train loss:2.250367877158217
# === epoch:34, train acc:0.22666666666666666, test acc:0.2189 ===
# train loss:2.245992534353492
# train loss:2.269904576630807
# train loss:2.2457096312069007
# === epoch:35, train acc:0.23333333333333334, test acc:0.219 ===
# train loss:2.218169834172694
# train loss:2.2441190533330926
# train loss:2.239191231608839
# === epoch:36, train acc:0.23333333333333334, test acc:0.2247 ===
# train loss:2.25203034393405
# train loss:2.269157940896824
# train loss:2.2437225180379614
# === epoch:37, train acc:0.23666666666666666, test acc:0.2282 ===
# train loss:2.263196405440535
# train loss:2.2318584018467815
# train loss:2.229751018183059
# === epoch:38, train acc:0.23666666666666666, test acc:0.2303 ===
# train loss:2.243532241831442
# train loss:2.2421628034637857
# train loss:2.2523077766423456
# === epoch:39, train acc:0.23333333333333334, test acc:0.2288 ===
# train loss:2.2442501672531416
# train loss:2.2314875581882294
# train loss:2.2622792464046246
# === epoch:40, train acc:0.23666666666666666, test acc:0.2333 ===
# train loss:2.2325032119200365
# train loss:2.2398778882732113
# train loss:2.241175591228362
# === epoch:41, train acc:0.24, test acc:0.2369 ===
# train loss:2.258305642777643
# train loss:2.2445638741114426
# train loss:2.255731424287747
# === epoch:42, train acc:0.24, test acc:0.2404 ===
# train loss:2.2406047434405787
# train loss:2.2508434095718846
# train loss:2.23526746858593
# === epoch:43, train acc:0.24333333333333335, test acc:0.2443 ===
# train loss:2.223478655084358
# train loss:2.233748437069228
# train loss:2.229701232810406
# === epoch:44, train acc:0.25, test acc:0.2452 ===
# train loss:2.2357863500747657
# train loss:2.2412162290985354
# train loss:2.230475055582557
# === epoch:45, train acc:0.25333333333333335, test acc:0.2508 ===
# train loss:2.2419265885818453
# train loss:2.2440148769979613
# train loss:2.234500137185083
# === epoch:46, train acc:0.25666666666666665, test acc:0.2539 ===
# train loss:2.2305983423536055
# train loss:2.2287266036162294
# train loss:2.2363065159460165
# === epoch:47, train acc:0.2633333333333333, test acc:0.255 ===
# train loss:2.246390025789429
# train loss:2.1974958764511654
# train loss:2.24756342938054
# === epoch:48, train acc:0.2733333333333333, test acc:0.256 ===
# train loss:2.236046530505396
# train loss:2.2111961473229473
# train loss:2.2039227153633565
# === epoch:49, train acc:0.27, test acc:0.2581 ===
# train loss:2.2316112864748883
# train loss:2.229301289552078
# train loss:2.235002521328703
# === epoch:50, train acc:0.27, test acc:0.2585 ===
# train loss:2.223166943169387
# train loss:2.225371618875102
# train loss:2.225089498445209
# === epoch:51, train acc:0.27, test acc:0.2595 ===
# train loss:2.2345114253392206
# train loss:2.22491692193048
# train loss:2.1911360381983407
# === epoch:52, train acc:0.27, test acc:0.2595 ===
# train loss:2.2144888165463548
# train loss:2.2213033320477384
# train loss:2.2292403055855985
# === epoch:53, train acc:0.2733333333333333, test acc:0.2609 ===
# train loss:2.213245418302887
# train loss:2.2248122941128643
# train loss:2.200885289011168
# === epoch:54, train acc:0.27666666666666667, test acc:0.2604 ===
# train loss:2.2275321586818255
# train loss:2.229470539276921
# train loss:2.2214026602739456
# === epoch:55, train acc:0.27666666666666667, test acc:0.2605 ===
# train loss:2.1955724714652356
# train loss:2.2355657308444035
# train loss:2.2160586276812584
# === epoch:56, train acc:0.27666666666666667, test acc:0.2598 ===
# train loss:2.2110109281851957
# train loss:2.188931569931819
# train loss:2.2128803038468514
# === epoch:57, train acc:0.27666666666666667, test acc:0.2613 ===
# train loss:2.209072921090941
# train loss:2.201525059089744
# train loss:2.193890178281988
# === epoch:58, train acc:0.27666666666666667, test acc:0.2597 ===
# train loss:2.200888542936844
# train loss:2.184127572312863
# train loss:2.2069007650661607
# === epoch:59, train acc:0.2833333333333333, test acc:0.2605 ===
# train loss:2.2400615872363123
# train loss:2.216192920476041
# train loss:2.203686211742395
# === epoch:60, train acc:0.2833333333333333, test acc:0.2615 ===
# train loss:2.2205909089379285
# train loss:2.18680142676475
# train loss:2.1848414137572187
# === epoch:61, train acc:0.2833333333333333, test acc:0.2603 ===
# train loss:2.192596771577032
# train loss:2.2070247333638595
# train loss:2.1619460993475896
# === epoch:62, train acc:0.2833333333333333, test acc:0.2602 ===
# train loss:2.210898448324842
# train loss:2.2154477263904377
# train loss:2.207386047689032
# === epoch:63, train acc:0.2833333333333333, test acc:0.2628 ===
# train loss:2.2101574285567933
# train loss:2.1960677268771476
# train loss:2.200903203432234
# === epoch:64, train acc:0.29333333333333333, test acc:0.2651 ===
# train loss:2.184449404149318
# train loss:2.1959474500978184
# train loss:2.218251774367645
# === epoch:65, train acc:0.29333333333333333, test acc:0.2652 ===
# train loss:2.1762774953841486
# train loss:2.2086166398780316
# train loss:2.1726963926774014
# === epoch:66, train acc:0.29333333333333333, test acc:0.2656 ===
# train loss:2.1861675996925074
# train loss:2.17021545248443
# train loss:2.2172010681875496
# === epoch:67, train acc:0.29333333333333333, test acc:0.2622 ===
# train loss:2.1786995077407085
# train loss:2.1982086125848763
# train loss:2.2009224458519174
# === epoch:68, train acc:0.2833333333333333, test acc:0.2627 ===
# train loss:2.191681304642624
# train loss:2.197294760836861
# train loss:2.245695466605699
# === epoch:69, train acc:0.29, test acc:0.2672 ===
# train loss:2.1849622885329736
# train loss:2.1941563456567668
# train loss:2.1498578404557507
# === epoch:70, train acc:0.29, test acc:0.2672 ===
# train loss:2.1522789870797663
# train loss:2.181047546425971
# train loss:2.197954114033826
# === epoch:71, train acc:0.2866666666666667, test acc:0.2704 ===
# train loss:2.192554808652749
# train loss:2.1752124141397755
# train loss:2.1763505927538644
# === epoch:72, train acc:0.2866666666666667, test acc:0.2692 ===
# train loss:2.1830780786434123
# train loss:2.2097414285947123
# train loss:2.1848965524040547
# === epoch:73, train acc:0.2966666666666667, test acc:0.2698 ===
# train loss:2.185634018965154
# train loss:2.149339439211597
# train loss:2.132416588189838
# === epoch:74, train acc:0.29333333333333333, test acc:0.2658 ===
# train loss:2.133255147902634
# train loss:2.1891834831860746
# train loss:2.204394805167409
# === epoch:75, train acc:0.2966666666666667, test acc:0.2671 ===
# train loss:2.1508042269297896
# train loss:2.1839551752631627
# train loss:2.1532748851209735
# === epoch:76, train acc:0.29333333333333333, test acc:0.268 ===
# train loss:2.1799617064247507
# train loss:2.11460020854822
# train loss:2.1949449318140246
# === epoch:77, train acc:0.29333333333333333, test acc:0.2692 ===
# train loss:2.1593496208651612
# train loss:2.132342579443518
# train loss:2.2134222105411654
# === epoch:78, train acc:0.2966666666666667, test acc:0.2719 ===
# train loss:2.1182598545181768
# train loss:2.201512328690954
# train loss:2.188065267203329
# === epoch:79, train acc:0.29333333333333333, test acc:0.2733 ===
# train loss:2.1513547758120253
# train loss:2.125902319163293
# train loss:2.1836987045278713
# === epoch:80, train acc:0.29333333333333333, test acc:0.2733 ===
# train loss:2.16514388484955
# train loss:2.155774201840018
# train loss:2.1596034213361537
# === epoch:81, train acc:0.29333333333333333, test acc:0.2733 ===
# train loss:2.1381447461676033
# train loss:2.161574643499639
# train loss:2.1883250517346333
# === epoch:82, train acc:0.2966666666666667, test acc:0.2745 ===
# train loss:2.1530767674483915
# train loss:2.1945331663111087
# train loss:2.172398239177904
# === epoch:83, train acc:0.30666666666666664, test acc:0.277 ===
# train loss:2.2151558582233886
# train loss:2.172374615684474
# train loss:2.056296996450692
# === epoch:84, train acc:0.30333333333333334, test acc:0.2792 ===
# train loss:2.1785150067200747
# train loss:2.1250936269924847
# train loss:2.169747355219673
# === epoch:85, train acc:0.30666666666666664, test acc:0.2801 ===
# train loss:2.159147350501666
# train loss:2.109231519572722
# train loss:2.1328663893445405
# === epoch:86, train acc:0.3, test acc:0.279 ===
# train loss:2.177720486977933
# train loss:2.183297783778416
# train loss:2.1351838541927446
# === epoch:87, train acc:0.30666666666666664, test acc:0.283 ===
# train loss:2.1642593833030865
# train loss:2.1321436394457325
# train loss:2.1703096445149823
# === epoch:88, train acc:0.30666666666666664, test acc:0.285 ===
# train loss:2.172972990166087
# train loss:2.1903724347466995
# train loss:2.089164143720823
# === epoch:89, train acc:0.30666666666666664, test acc:0.2851 ===
# train loss:2.1787241344615045
# train loss:2.1500403349579416
# train loss:2.1668820346167754
# === epoch:90, train acc:0.31333333333333335, test acc:0.2859 ===
# train loss:2.169669732935418
# train loss:2.1431073845852175
# train loss:2.1550185231344434
# === epoch:91, train acc:0.32, test acc:0.2856 ===
# train loss:2.166729468003683
# train loss:2.124964187582784
# train loss:2.1550632227287316
# === epoch:92, train acc:0.31666666666666665, test acc:0.2874 ===
# train loss:2.146682240655206
# train loss:2.1358808213605416
# train loss:2.174775439476403
# === epoch:93, train acc:0.31666666666666665, test acc:0.288 ===
# train loss:2.1302133340995764
# train loss:2.1344182940152834
# train loss:2.0877312281144964
# === epoch:94, train acc:0.3233333333333333, test acc:0.2892 ===
# train loss:2.1335286308110133
# train loss:2.1653777674099666
# train loss:2.087933010103714
# === epoch:95, train acc:0.3233333333333333, test acc:0.2888 ===
# train loss:2.108502470592552
# train loss:2.1084380732009715
# train loss:2.1539620719477766
# === epoch:96, train acc:0.3233333333333333, test acc:0.2904 ===
# train loss:2.1508456043784645
# train loss:2.1442237199484273
# train loss:2.0983332251513995
# === epoch:97, train acc:0.32666666666666666, test acc:0.2912 ===
# train loss:2.096930218325262
# train loss:2.122159150971245
# train loss:2.070094579351958
# === epoch:98, train acc:0.32666666666666666, test acc:0.2915 ===
# train loss:2.124241963044558
# train loss:2.1035785806832394
# train loss:2.101554799723798
# === epoch:99, train acc:0.33, test acc:0.2928 ===
# train loss:2.0899812922865575
# train loss:2.0619496830494928
# train loss:2.1006907737321403
# === epoch:100, train acc:0.32666666666666666, test acc:0.2907 ===
# train loss:2.0855407507873185
# train loss:2.0740728148231904
# train loss:2.134988569282744
# === epoch:101, train acc:0.32, test acc:0.2904 ===
# train loss:2.095056490127437
# train loss:2.1268944397245777
# train loss:2.0201101331837648
# === epoch:102, train acc:0.3233333333333333, test acc:0.2921 ===
# train loss:2.0730373062014458
# train loss:2.1423586189851758
# train loss:2.1259915406297534
# === epoch:103, train acc:0.3233333333333333, test acc:0.2917 ===
# train loss:2.057291840121499
# train loss:2.0489069519973673
# train loss:2.071348080787001
# === epoch:104, train acc:0.3233333333333333, test acc:0.2908 ===
# train loss:2.110043378806912
# train loss:2.119409835268914
# train loss:2.063047881233175
# === epoch:105, train acc:0.32, test acc:0.292 ===
# train loss:2.120823254460937
# train loss:2.076670504773058
# train loss:2.114952146486915
# === epoch:106, train acc:0.32, test acc:0.2927 ===
# train loss:2.1144173343724666
# train loss:2.0967157070887623
# train loss:2.0371792162581093
# === epoch:107, train acc:0.32, test acc:0.293 ===
# train loss:2.0826684327749665
# train loss:1.993213111366518
# train loss:2.0364818643243496
# === epoch:108, train acc:0.31666666666666665, test acc:0.2918 ===
# train loss:2.100339454699212
# train loss:2.117518552534862
# train loss:2.1204673024397556
# === epoch:109, train acc:0.31666666666666665, test acc:0.292 ===
# train loss:2.0290068539491246
# train loss:2.0980278045731002
# train loss:1.9515750219868782
# === epoch:110, train acc:0.31666666666666665, test acc:0.2928 ===
# train loss:2.1067839182019923
# train loss:2.139896591292484
# train loss:2.006986105699454
# === epoch:111, train acc:0.31333333333333335, test acc:0.2919 ===
# train loss:2.0494885060121257
# train loss:2.072888978727289
# train loss:2.1038420906566473
# === epoch:112, train acc:0.3233333333333333, test acc:0.2918 ===
# train loss:2.0146935901822554
# train loss:2.0638155964940106
# train loss:2.0043891538602137
# === epoch:113, train acc:0.32, test acc:0.2919 ===
# train loss:2.0359374329563322
# train loss:2.0248903938873504
# train loss:2.015292871802529
# === epoch:114, train acc:0.3233333333333333, test acc:0.2912 ===
# train loss:2.029704392694207
# train loss:2.059666972848871
# train loss:2.076683114397118
# === epoch:115, train acc:0.32, test acc:0.2923 ===
# train loss:1.981812252792008
# train loss:1.9649173905909523
# train loss:1.9953827279826357
# === epoch:116, train acc:0.32, test acc:0.2908 ===
# train loss:2.0804111849790248
# train loss:2.1074895520292567
# train loss:2.0283938075154775
# === epoch:117, train acc:0.3233333333333333, test acc:0.2912 ===
# train loss:2.0317827356494034
# train loss:1.9739512400402648
# train loss:2.056696833226241
# === epoch:118, train acc:0.32, test acc:0.2899 ===
# train loss:2.0392850063102914
# train loss:2.0476015287445724
# train loss:2.0377278086135364
# === epoch:119, train acc:0.3233333333333333, test acc:0.2905 ===
# train loss:2.1019625079843194
# train loss:2.066373209497377
# train loss:1.9996395590991216
# === epoch:120, train acc:0.33, test acc:0.291 ===
# train loss:2.056949132756438
# train loss:1.9917087865357046
# train loss:2.029805557973045
# === epoch:121, train acc:0.33, test acc:0.2916 ===
# train loss:2.1422853845441847
# train loss:2.0395967963833845
# train loss:1.999137792621918
# === epoch:122, train acc:0.33, test acc:0.2933 ===
# train loss:1.989123014249197
# train loss:2.002289426837484
# train loss:2.0681286249245625
# === epoch:123, train acc:0.32666666666666666, test acc:0.2934 ===
# train loss:2.0546448321197306
# train loss:2.0073266271254457
# train loss:1.9555712812026098
# === epoch:124, train acc:0.33, test acc:0.2945 ===
# train loss:2.0458070660949486
# train loss:1.9457995365357466
# train loss:1.9232162231316676
# === epoch:125, train acc:0.3333333333333333, test acc:0.2935 ===
# train loss:2.0074512970247587
# train loss:2.0072793177994015
# train loss:2.0326215791259368
# === epoch:126, train acc:0.33, test acc:0.2936 ===
# train loss:2.1216687991496452
# train loss:1.9635996224052465
# train loss:2.025224112612284
# === epoch:127, train acc:0.33, test acc:0.2943 ===
# train loss:2.033902346327848
# train loss:2.004991022986042
# train loss:2.0389112368353395
# === epoch:128, train acc:0.33, test acc:0.2933 ===
# train loss:2.0850734980805594
# train loss:1.9853078097613548
# train loss:2.023896624807505
# === epoch:129, train acc:0.3333333333333333, test acc:0.2942 ===
# train loss:1.9651649069476218
# train loss:1.912338293917358
# train loss:1.986763857297708
# === epoch:130, train acc:0.33, test acc:0.2953 ===
# train loss:1.9988254727975339
# train loss:1.9795703708015528
# train loss:2.007054064414652
# === epoch:131, train acc:0.33, test acc:0.2951 ===
# train loss:1.9540125140763127
# train loss:1.9218826407083582
# train loss:1.9912261924819137
# === epoch:132, train acc:0.33, test acc:0.295 ===
# train loss:1.9347910506739523
# train loss:1.9962143750734789
# train loss:2.041718968439332
# === epoch:133, train acc:0.33, test acc:0.2952 ===
# train loss:1.9617673940104832
# train loss:1.9066331776524317
# train loss:1.9608419408065183
# === epoch:134, train acc:0.33, test acc:0.2953 ===
# train loss:2.0300479709622725
# train loss:1.95351311531831
# train loss:1.9522764966762296
# === epoch:135, train acc:0.32666666666666666, test acc:0.2953 ===
# train loss:2.00918256642951
# train loss:2.018804558479331
# train loss:1.9319887099438986
# === epoch:136, train acc:0.32666666666666666, test acc:0.2976 ===
# train loss:1.9396952361001871
# train loss:1.9669134541637556
# train loss:1.9727113120225395
# === epoch:137, train acc:0.3333333333333333, test acc:0.2984 ===
# train loss:1.9437855074411152
# train loss:1.962713449721472
# train loss:2.008363892110845
# === epoch:138, train acc:0.33, test acc:0.2999 ===
# train loss:1.9722798089345341
# train loss:2.012068420884765
# train loss:2.016360215752517
# === epoch:139, train acc:0.34, test acc:0.3001 ===
# train loss:1.948507582792457
# train loss:2.0280438193589174
# train loss:2.008711975745673
# === epoch:140, train acc:0.3433333333333333, test acc:0.3022 ===
# train loss:2.015221095916374
# train loss:1.9977639894896506
# train loss:1.951877121194255
# === epoch:141, train acc:0.3466666666666667, test acc:0.3051 ===
# train loss:1.9206964053339066
# train loss:1.8890583887955155
# train loss:1.9671453441716507
# === epoch:142, train acc:0.33666666666666667, test acc:0.301 ===
# train loss:1.9142532738033367
# train loss:1.8988268658221605
# train loss:1.9900648675247903
# === epoch:143, train acc:0.33666666666666667, test acc:0.3008 ===
# train loss:1.8789467151837562
# train loss:1.9010018713251666
# train loss:2.007470065623443
# === epoch:144, train acc:0.34, test acc:0.3008 ===
# train loss:1.8781435466491425
# train loss:2.0137431290466887
# train loss:1.964054309274766
# === epoch:145, train acc:0.3433333333333333, test acc:0.3032 ===
# train loss:1.8695218862913876
# train loss:1.9381262231343266
# train loss:2.0161749189623563
# === epoch:146, train acc:0.3433333333333333, test acc:0.3044 ===
# train loss:1.9261607686353512
# train loss:2.003149310665317
# train loss:1.8598113940649805
# === epoch:147, train acc:0.35, test acc:0.3056 ===
# train loss:1.9729211833345122
# train loss:1.9437492107604186
# train loss:1.9685812767458541
# === epoch:148, train acc:0.35, test acc:0.3086 ===
# train loss:1.8873619631610956
# train loss:1.9061870864614314
# train loss:1.970065236179726
# === epoch:149, train acc:0.35, test acc:0.3084 ===
# train loss:2.0376679788861067
# train loss:1.9872663127946704
# train loss:1.9067707494903936
# === epoch:150, train acc:0.35, test acc:0.3088 ===
# train loss:1.87064388749561
# train loss:1.9408514199321625
# train loss:1.9368960970973759
# === epoch:151, train acc:0.35333333333333333, test acc:0.3104 ===
# train loss:1.8764111073690037
# train loss:1.9021630221703125
# train loss:1.8715191994480487
# === epoch:152, train acc:0.35, test acc:0.3106 ===
# train loss:2.02694958192737
# train loss:1.8835747646027434
# train loss:1.9779576431742296
# === epoch:153, train acc:0.35, test acc:0.3116 ===
# train loss:1.895912380634453
# train loss:1.9843752682972522
# train loss:1.9388290811929165
# === epoch:154, train acc:0.3466666666666667, test acc:0.312 ===
# train loss:1.9057439534155254
# train loss:1.9019884915222744
# train loss:1.8832668317148458
# === epoch:155, train acc:0.35, test acc:0.3118 ===
# train loss:1.9365186484923098
# train loss:1.8497385246870963
# train loss:1.8384918524340697
# === epoch:156, train acc:0.3466666666666667, test acc:0.3119 ===
# train loss:1.9250154927284229
# train loss:1.9256204635497154
# train loss:1.897595892338152
# === epoch:157, train acc:0.3466666666666667, test acc:0.3111 ===
# train loss:1.8980120368637787
# train loss:1.9365839581326127
# train loss:1.8741281852666922
# === epoch:158, train acc:0.3466666666666667, test acc:0.311 ===
# train loss:1.9547198805080372
# train loss:1.9269841466277635
# train loss:1.9278290550434403
# === epoch:159, train acc:0.3466666666666667, test acc:0.3116 ===
# train loss:1.8581383237350795
# train loss:1.9467525994044896
# train loss:1.8059118877853617
# === epoch:160, train acc:0.35, test acc:0.315 ===
# train loss:1.7949641479214902
# train loss:1.9016319454888395
# train loss:2.0183337213890904
# === epoch:161, train acc:0.35, test acc:0.3172 ===
# train loss:1.920913863446644
# train loss:1.8967362652128545
# train loss:1.905798018753732
# === epoch:162, train acc:0.37666666666666665, test acc:0.3224 ===
# train loss:1.9533204856207516
# train loss:1.85477217070887
# train loss:1.8655249906559954
# === epoch:163, train acc:0.37666666666666665, test acc:0.3196 ===
# train loss:1.8752884316114538
# train loss:1.9712189986401523
# train loss:1.930422422322061
# === epoch:164, train acc:0.37333333333333335, test acc:0.3172 ===
# train loss:1.9176034579296475
# train loss:1.87156372583207
# train loss:1.8979996807780566
# === epoch:165, train acc:0.37333333333333335, test acc:0.3199 ===
# train loss:1.9617802506631055
# train loss:1.9529659174937313
# train loss:1.8094489404298284
# === epoch:166, train acc:0.37333333333333335, test acc:0.3203 ===
# train loss:1.9044404316948922
# train loss:1.926240025639369
# train loss:1.8910813152758434
# === epoch:167, train acc:0.38333333333333336, test acc:0.3236 ===
# train loss:1.8615985860111914
# train loss:1.8448045090483545
# train loss:1.9136234364029294
# === epoch:168, train acc:0.38333333333333336, test acc:0.324 ===
# train loss:1.8179503430582076
# train loss:1.851622245270381
# train loss:1.9860771619636108
# === epoch:169, train acc:0.37333333333333335, test acc:0.3214 ===
# train loss:1.8942426032655237
# train loss:1.8426820754902549
# train loss:1.9159615216682568
# === epoch:170, train acc:0.37333333333333335, test acc:0.3216 ===
# train loss:1.9034610886766645
# train loss:1.911620674481853
# train loss:1.7826553721758844
# === epoch:171, train acc:0.38333333333333336, test acc:0.3223 ===
# train loss:1.927201076512699
# train loss:1.8695235371604313
# train loss:1.9373299949894371
# === epoch:172, train acc:0.38333333333333336, test acc:0.3255 ===
# train loss:1.841592315104595
# train loss:1.9002876455422608
# train loss:1.88530282872953
# === epoch:173, train acc:0.38333333333333336, test acc:0.3254 ===
# train loss:1.847587248216233
# train loss:1.8994090714382237
# train loss:1.8647827549389893
# === epoch:174, train acc:0.38333333333333336, test acc:0.325 ===
# train loss:1.8710809468510556
# train loss:1.8937681600205596
# train loss:1.7808414624211482
# === epoch:175, train acc:0.38333333333333336, test acc:0.3269 ===
# train loss:1.8168976140629007
# train loss:1.8633543999432924
# train loss:1.8041835407280755
# === epoch:176, train acc:0.38333333333333336, test acc:0.3289 ===
# train loss:1.876010441131388
# train loss:1.8374246083441783
# train loss:1.7774061618969643
# === epoch:177, train acc:0.38333333333333336, test acc:0.3281 ===
# train loss:1.7840556955780225
# train loss:1.8396155912011876
# train loss:1.7886297695658344
# === epoch:178, train acc:0.38333333333333336, test acc:0.3277 ===
# train loss:1.8091136904563518
# train loss:1.867561626433078
# train loss:1.8609275328854116
# === epoch:179, train acc:0.37666666666666665, test acc:0.3265 ===
# train loss:1.8179371189751925
# train loss:1.8956097037124573
# train loss:1.9498454074484886
# === epoch:180, train acc:0.37666666666666665, test acc:0.3256 ===
# train loss:1.8252126362410217
# train loss:1.8109477302296575
# train loss:1.8747187881528768
# === epoch:181, train acc:0.37666666666666665, test acc:0.326 ===
# train loss:1.9116876599399024
# train loss:1.6945518208070334
# train loss:1.861732748318335
# === epoch:182, train acc:0.38333333333333336, test acc:0.3262 ===
# train loss:1.9079753053434478
# train loss:1.6451928565232878
# train loss:1.8495004427249768
# === epoch:183, train acc:0.39, test acc:0.3278 ===
# train loss:1.8875196953333753
# train loss:1.7040768229516507
# train loss:1.7849392021044326
# === epoch:184, train acc:0.38333333333333336, test acc:0.3257 ===
# train loss:1.8246051993375079
# train loss:1.7368837413681357
# train loss:1.7942546264455017
# === epoch:185, train acc:0.38666666666666666, test acc:0.3262 ===
# train loss:1.7275496917059274
# train loss:1.7747858425682008
# train loss:1.8966972174394794
# === epoch:186, train acc:0.38666666666666666, test acc:0.3287 ===
# train loss:1.8332204680684558
# train loss:1.7186057748226542
# train loss:1.872786381294618
# === epoch:187, train acc:0.39, test acc:0.3343 ===
# train loss:1.7904596965543336
# train loss:1.8673059748306062
# train loss:1.8145763723279307
# === epoch:188, train acc:0.38666666666666666, test acc:0.3358 ===
# train loss:1.8468053537854865
# train loss:1.7292473030581363
# train loss:1.7654160735292819
# === epoch:189, train acc:0.38666666666666666, test acc:0.3341 ===
# train loss:1.9044733898867494
# train loss:1.8144428378802586
# train loss:1.810271620065184
# === epoch:190, train acc:0.38666666666666666, test acc:0.3329 ===
# train loss:1.709410271876493
# train loss:1.8724728580466752
# train loss:1.8740526598530416
# === epoch:191, train acc:0.39, test acc:0.3359 ===
# train loss:1.8518472049529249
# train loss:1.7376272434117386
# train loss:1.7888169045620967
# === epoch:192, train acc:0.3933333333333333, test acc:0.3375 ===
# train loss:1.9817406798968158
# train loss:1.736820807303903
# train loss:1.8474607755269212
# === epoch:193, train acc:0.41, test acc:0.3406 ===
# train loss:1.7546107505290127
# train loss:1.865334018034195
# train loss:1.8606352761232654
# === epoch:194, train acc:0.4033333333333333, test acc:0.3409 ===
# train loss:1.810778716765904
# train loss:1.7428962465641242
# train loss:1.799953451809022
# === epoch:195, train acc:0.4033333333333333, test acc:0.3413 ===
# train loss:1.7888827233590578
# train loss:1.7020173095958182
# train loss:1.7946910807653436
# === epoch:196, train acc:0.4, test acc:0.3399 ===
# train loss:1.7706306872748383
# train loss:1.7125860040562477
# train loss:1.80279753716702
# === epoch:197, train acc:0.3933333333333333, test acc:0.3385 ===
# train loss:1.829600423139035
# train loss:1.6297918529683992
# train loss:1.6131640079699148
# === epoch:198, train acc:0.39, test acc:0.3355 ===
# train loss:1.8148314400379497
# train loss:1.8267503749597374
# train loss:1.7913292256905864
# === epoch:199, train acc:0.39666666666666667, test acc:0.3366 ===
# train loss:1.7976111944922837
# train loss:1.758133630106804
# train loss:1.8292115602651402
# === epoch:200, train acc:0.39666666666666667, test acc:0.3387 ===
# train loss:1.7650839930280724
# train loss:1.8555489332028996
# train loss:1.7930908888403878
# === epoch:201, train acc:0.4033333333333333, test acc:0.341 ===
# train loss:1.7231422008716424
# train loss:1.6752036055945558
# train loss:1.768812346799246
# === epoch:202, train acc:0.4066666666666667, test acc:0.3437 ===
# train loss:1.8065851818819405
# train loss:1.6387582704921586
# train loss:1.727959737651683
# === epoch:203, train acc:0.42, test acc:0.3475 ===
# train loss:1.7529114044522325
# train loss:1.7197616192681529
# train loss:1.8080916326597087
# === epoch:204, train acc:0.42, test acc:0.351 ===
# train loss:1.7325006260547031
# train loss:1.8081884636364123
# train loss:1.7217470340218965
# === epoch:205, train acc:0.4066666666666667, test acc:0.3412 ===
# train loss:1.7357994391078921
# train loss:1.8268782212793828
# train loss:1.7246325584166007
# === epoch:206, train acc:0.4066666666666667, test acc:0.3391 ===
# train loss:1.8221956383982894
# train loss:1.66597872144635
# train loss:1.7694130925968288
# === epoch:207, train acc:0.4166666666666667, test acc:0.3447 ===
# train loss:1.7061601760153982
# train loss:1.6648337285176353
# train loss:1.7219573448130676
# === epoch:208, train acc:0.4, test acc:0.3403 ===
# train loss:1.6871359085898505
# train loss:1.789740820351491
# train loss:1.7269200657528037
# === epoch:209, train acc:0.4033333333333333, test acc:0.3417 ===
# train loss:1.669897157150308
# train loss:1.665627881970694
# train loss:1.7220640466784298
# === epoch:210, train acc:0.4033333333333333, test acc:0.341 ===
# train loss:1.7377822485213823
# train loss:1.7491205178686289
# train loss:1.5877253145513945
# === epoch:211, train acc:0.4, test acc:0.3398 ===
# train loss:1.6287514955742919
# train loss:1.6925095260870164
# train loss:1.623373638245538
# === epoch:212, train acc:0.41, test acc:0.3467 ===
# train loss:1.622294716700201
# train loss:1.6525859243662055
# train loss:1.7022367136021725
# === epoch:213, train acc:0.4033333333333333, test acc:0.3431 ===
# train loss:1.778968701633416
# train loss:1.649658388622281
# train loss:1.824062708231401
# === epoch:214, train acc:0.4033333333333333, test acc:0.3459 ===
# train loss:1.6717890034761203
# train loss:1.6816323456001623
# train loss:1.6328126420289777
# === epoch:215, train acc:0.41, test acc:0.3462 ===
# train loss:1.648956015887661
# train loss:1.7055382585754089
# train loss:1.7123283561913702
# === epoch:216, train acc:0.42, test acc:0.3515 ===
# train loss:1.6016815286229535
# train loss:1.6470855427983997
# train loss:1.668034330377863
# === epoch:217, train acc:0.42333333333333334, test acc:0.3537 ===
# train loss:1.6521545385421477
# train loss:1.6885272977488952
# train loss:1.5744269664445352
# === epoch:218, train acc:0.42, test acc:0.3554 ===
# train loss:1.5614652671549765
# train loss:1.7085917580383907
# train loss:1.6038878276729127
# === epoch:219, train acc:0.4166666666666667, test acc:0.3509 ===
# train loss:1.6228762015779048
# train loss:1.6753270195797192
# train loss:1.724137928214085
# === epoch:220, train acc:0.4266666666666667, test acc:0.3528 ===
# train loss:1.6009599801303431
# train loss:1.6723376195897919
# train loss:1.5757254779808876
# === epoch:221, train acc:0.42333333333333334, test acc:0.3537 ===
# train loss:1.6011048554408713
# train loss:1.6789575766138014
# train loss:1.5386195930107456
# === epoch:222, train acc:0.41333333333333333, test acc:0.3473 ===
# train loss:1.526905947655741
# train loss:1.693249844739329
# train loss:1.5950398647336397
# === epoch:223, train acc:0.41333333333333333, test acc:0.3469 ===
# train loss:1.6632324182731517
# train loss:1.700263853855434
# train loss:1.6567852159591792
# === epoch:224, train acc:0.42, test acc:0.349 ===
# train loss:1.5894122263371337
# train loss:1.7709805527041993
# train loss:1.5585253908014665
# === epoch:225, train acc:0.42, test acc:0.3517 ===
# train loss:1.770559744745807
# train loss:1.5803750057212722
# train loss:1.5234587893448492
# === epoch:226, train acc:0.42, test acc:0.3505 ===
# train loss:1.6416831594439754
# train loss:1.667573581596374
# train loss:1.5954995071859677
# === epoch:227, train acc:0.43333333333333335, test acc:0.3651 ===
# train loss:1.625266011094449
# train loss:1.6747883591518076
# train loss:1.6129462923180458
# === epoch:228, train acc:0.44, test acc:0.3705 ===
# train loss:1.4732822873778935
# train loss:1.6858631075058275
# train loss:1.6286695392530024
# === epoch:229, train acc:0.43666666666666665, test acc:0.3737 ===
# train loss:1.6160679336976795
# train loss:1.6005706688098333
# train loss:1.635280931215982
# === epoch:230, train acc:0.43666666666666665, test acc:0.3754 ===
# train loss:1.4691312458247383
# train loss:1.6618017185351364
# train loss:1.743153043211029
# === epoch:231, train acc:0.44, test acc:0.3733 ===
# train loss:1.6255618032137065
# train loss:1.6622874522213846
# train loss:1.7360456403480256
# === epoch:232, train acc:0.43, test acc:0.3689 ===
# train loss:1.5858314467199184
# train loss:1.537000171671171
# train loss:1.6391877281750142
# === epoch:233, train acc:0.43666666666666665, test acc:0.3741 ===
# train loss:1.621574133287845
# train loss:1.6188113450012518
# train loss:1.531405479828348
# === epoch:234, train acc:0.43, test acc:0.3706 ===
# train loss:1.7003921943315459
# train loss:1.557938118676
# train loss:1.6458975468841461
# === epoch:235, train acc:0.4266666666666667, test acc:0.373 ===
# train loss:1.7436577643653626
# train loss:1.5502502540068586
# train loss:1.63923643721546
# === epoch:236, train acc:0.43333333333333335, test acc:0.3759 ===
# train loss:1.5900820905127748
# train loss:1.6444922045793433
# train loss:1.4979125546476877
# === epoch:237, train acc:0.4533333333333333, test acc:0.3806 ===
# train loss:1.6241934758265706
# train loss:1.5752017466240542
# train loss:1.5222333486787714
# === epoch:238, train acc:0.45, test acc:0.3799 ===
# train loss:1.5965186171823604
# train loss:1.4857587258870617
# train loss:1.583388279373462
# === epoch:239, train acc:0.45666666666666667, test acc:0.3815 ===
# train loss:1.6882771489819854
# train loss:1.4265729194253323
# train loss:1.6184134472026692
# === epoch:240, train acc:0.4666666666666667, test acc:0.3907 ===
# train loss:1.5414268713840213
# train loss:1.5656088011563398
# train loss:1.6791303350145745
# === epoch:241, train acc:0.4666666666666667, test acc:0.391 ===
# train loss:1.5540648568911741
# train loss:1.6593430028662148
# train loss:1.5262994963598795
# === epoch:242, train acc:0.47333333333333333, test acc:0.3921 ===
# train loss:1.5596143829125415
# train loss:1.390402538855791
# train loss:1.511333763022691
# === epoch:243, train acc:0.4633333333333333, test acc:0.3882 ===
# train loss:1.478486713241353
# train loss:1.5484775236142467
# train loss:1.5272282979270884
# === epoch:244, train acc:0.45666666666666667, test acc:0.3832 ===
# train loss:1.5414253594081182
# train loss:1.4997813367659385
# train loss:1.701192643616812
# === epoch:245, train acc:0.47, test acc:0.3895 ===
# train loss:1.5599625335415643
# train loss:1.5075511356857887
# train loss:1.5220552188753433
# === epoch:246, train acc:0.45666666666666667, test acc:0.3871 ===
# train loss:1.59065765050453
# train loss:1.449120930526206
# train loss:1.5750836005823257
# === epoch:247, train acc:0.4533333333333333, test acc:0.3913 ===
# train loss:1.5049797236482387
# train loss:1.5810367042789013
# train loss:1.4645361501088663
# === epoch:248, train acc:0.45666666666666667, test acc:0.3932 ===
# train loss:1.485867785880036
# train loss:1.486073669369781
# train loss:1.5906383294163737
# === epoch:249, train acc:0.4766666666666667, test acc:0.3997 ===
# train loss:1.6054230313970712
# train loss:1.490117954456511
# train loss:1.490855759731308
# === epoch:250, train acc:0.48, test acc:0.4015 ===
# train loss:1.3772771389657397
# train loss:1.4321230116583719
# train loss:1.5841204587877495
# === epoch:251, train acc:0.47, test acc:0.3935 ===
# train loss:1.5101564715242313
# train loss:1.5190621585988087
# train loss:1.4519673259331538
# === epoch:252, train acc:0.4766666666666667, test acc:0.3986 ===
# train loss:1.5013200667870168
# train loss:1.512456421115308
# train loss:1.494034721797174
# === epoch:253, train acc:0.47333333333333333, test acc:0.3985 ===
# train loss:1.4206897682532025
# train loss:1.4906925135696707
# train loss:1.4719061257197976
# === epoch:254, train acc:0.4766666666666667, test acc:0.3991 ===
# train loss:1.4435327446489672
# train loss:1.4867210408709755
# train loss:1.5835542275325463
# === epoch:255, train acc:0.4866666666666667, test acc:0.4061 ===
# train loss:1.6137148931985754
# train loss:1.535856121470101
# train loss:1.4409189054390033
# === epoch:256, train acc:0.49, test acc:0.4077 ===
# train loss:1.441278089551921
# train loss:1.404251937643851
# train loss:1.5068476714774601
# === epoch:257, train acc:0.49, test acc:0.4083 ===
# train loss:1.468001349954188
# train loss:1.4150207957420815
# train loss:1.5254727880461518
# === epoch:258, train acc:0.49333333333333335, test acc:0.4106 ===
# train loss:1.476956867132829
# train loss:1.4389907880393105
# train loss:1.487271540913515
# === epoch:259, train acc:0.5033333333333333, test acc:0.4149 ===
# train loss:1.4494507147539124
# train loss:1.450214979923185
# train loss:1.4242406480296097
# === epoch:260, train acc:0.5033333333333333, test acc:0.4121 ===
# train loss:1.4017390085012156
# train loss:1.3681325244246187
# train loss:1.4055960129591494
# === epoch:261, train acc:0.5066666666666667, test acc:0.4151 ===
# train loss:1.4796385719983394
# train loss:1.402903829799339
# train loss:1.4274467730518634
# === epoch:262, train acc:0.5133333333333333, test acc:0.4157 ===
# train loss:1.443700118425666
# train loss:1.4586572320780258
# train loss:1.4096864814421353
# === epoch:263, train acc:0.5133333333333333, test acc:0.4155 ===
# train loss:1.4668987787167904
# train loss:1.448910154277484
# train loss:1.4101638676930428
# === epoch:264, train acc:0.5133333333333333, test acc:0.4178 ===
# train loss:1.451933897961944
# train loss:1.397062960588265
# train loss:1.3861980061916865
# === epoch:265, train acc:0.5133333333333333, test acc:0.4205 ===
# train loss:1.5321926646910742
# train loss:1.316596859010034
# train loss:1.483620204684641
# === epoch:266, train acc:0.5166666666666667, test acc:0.4252 ===
# train loss:1.4216753735881518
# train loss:1.3939379975460902
# train loss:1.5300844627135648
# === epoch:267, train acc:0.5233333333333333, test acc:0.4304 ===
# train loss:1.523444854154994
# train loss:1.431075718692145
# train loss:1.4845406682523736
# === epoch:268, train acc:0.5233333333333333, test acc:0.4319 ===
# train loss:1.4086194689950722
# train loss:1.421423899108647
# train loss:1.3204130673326182
# === epoch:269, train acc:0.5266666666666666, test acc:0.4358 ===
# train loss:1.3945672470353678
# train loss:1.4536027000035552
# train loss:1.3582395471190725
# === epoch:270, train acc:0.5333333333333333, test acc:0.4399 ===
# train loss:1.4936862676190596
# train loss:1.4051221252859045
# train loss:1.2902806787500805
# === epoch:271, train acc:0.54, test acc:0.4377 ===
# train loss:1.396036375224461
# train loss:1.4917736303397209
# train loss:1.3283823066333549
# === epoch:272, train acc:0.5366666666666666, test acc:0.4396 ===
# train loss:1.343870566970326
# train loss:1.4353639599694739
# train loss:1.339537863225697
# === epoch:273, train acc:0.5366666666666666, test acc:0.4472 ===
# train loss:1.241653448991107
# train loss:1.384703110911375
# train loss:1.4564605841366096
# === epoch:274, train acc:0.5466666666666666, test acc:0.4485 ===
# train loss:1.3292496443243274
# train loss:1.361633251556473
# train loss:1.4041888384267844
# === epoch:275, train acc:0.55, test acc:0.4529 ===
# train loss:1.4315196115013853
# train loss:1.391530240895207
# train loss:1.3246526750646224
# === epoch:276, train acc:0.5466666666666666, test acc:0.4485 ===
# train loss:1.4207173324832219
# train loss:1.3681358205312235
# train loss:1.452017749143061
# === epoch:277, train acc:0.5433333333333333, test acc:0.4477 ===
# train loss:1.4780540755993292
# train loss:1.504389528759315
# train loss:1.3319450208989765
# === epoch:278, train acc:0.5433333333333333, test acc:0.4482 ===
# train loss:1.451294112480304
# train loss:1.3838467471607938
# train loss:1.3391645239156538
# === epoch:279, train acc:0.5533333333333333, test acc:0.4555 ===
# train loss:1.2801570446445683
# train loss:1.4568690115522422
# train loss:1.3159008371318068
# === epoch:280, train acc:0.5533333333333333, test acc:0.4585 ===
# train loss:1.3061591784295612
# train loss:1.301890239284542
# train loss:1.2854835909213655
# === epoch:281, train acc:0.55, test acc:0.4515 ===
# train loss:1.2798441051558185
# train loss:1.4116615816109137
# train loss:1.2161885630088145
# === epoch:282, train acc:0.5533333333333333, test acc:0.4487 ===
# train loss:1.3263107506061582
# train loss:1.3919482864247976
# train loss:1.3621594042330167
# === epoch:283, train acc:0.56, test acc:0.4512 ===
# train loss:1.3272990051793188
# train loss:1.2876379706630134
# train loss:1.2816318107102205
# === epoch:284, train acc:0.55, test acc:0.4442 ===
# train loss:1.3186910692067417
# train loss:1.296060959054001
# train loss:1.3251817123783831
# === epoch:285, train acc:0.5566666666666666, test acc:0.4452 ===
# train loss:1.3657260681975825
# train loss:1.2249366848872743
# train loss:1.3636899492075738
# === epoch:286, train acc:0.5633333333333334, test acc:0.4503 ===
# train loss:1.3617521493882203
# train loss:1.2299794438359388
# train loss:1.3445420028392647
# === epoch:287, train acc:0.5566666666666666, test acc:0.4483 ===
# train loss:1.249336989626344
# train loss:1.2126999523375326
# train loss:1.3691376946810485
# === epoch:288, train acc:0.5666666666666667, test acc:0.4516 ===
# train loss:1.2045646385736655
# train loss:1.2530828687204763
# train loss:1.3733090381604385
# === epoch:289, train acc:0.5666666666666667, test acc:0.4527 ===
# train loss:1.2780457246141639
# train loss:1.2572966699693557
# train loss:1.4437084845187524
# === epoch:290, train acc:0.57, test acc:0.4641 ===
# train loss:1.3440135363944052
# train loss:1.2150952099120422
# train loss:1.3414611238062415
# === epoch:291, train acc:0.5733333333333334, test acc:0.466 ===
# train loss:1.3645620661711175
# train loss:1.2261939221073286
# train loss:1.2673373506675032
# === epoch:292, train acc:0.58, test acc:0.4751 ===
# train loss:1.259498352474731
# train loss:1.2277602511427625
# train loss:1.2085210047060266
# === epoch:293, train acc:0.58, test acc:0.4708 ===
# train loss:1.3143672866910827
# train loss:1.334670243884628
# train loss:1.274966545696694
# === epoch:294, train acc:0.5866666666666667, test acc:0.4724 ===
# train loss:1.275157646087944
# train loss:1.245860260563867
# train loss:1.3575487598721176
# === epoch:295, train acc:0.5866666666666667, test acc:0.4748 ===
# train loss:1.2972911505074347
# train loss:1.2578700014192703
# train loss:1.2992305073415336
# === epoch:296, train acc:0.59, test acc:0.4792 ===
# train loss:1.2177281582623372
# train loss:1.1828915734749146
# train loss:1.0672105422268618
# === epoch:297, train acc:0.5833333333333334, test acc:0.4747 ===
# train loss:1.3481429088222436
# train loss:1.3318105287806619
# train loss:1.315482143300186
# === epoch:298, train acc:0.5866666666666667, test acc:0.4772 ===
# train loss:1.2926104627007566
# train loss:1.3525394634513912
# train loss:1.2537310546480693
# === epoch:299, train acc:0.5833333333333334, test acc:0.4807 ===
# train loss:1.306003628882688
# train loss:1.213664510986143
# train loss:1.3089443201034532
# === epoch:300, train acc:0.5933333333333334, test acc:0.4863 ===
# train loss:1.3093232198764435
# train loss:1.1108315678718748
# train loss:1.275530029043101
# === epoch:301, train acc:0.5966666666666667, test acc:0.4859 ===
# train loss:1.1372713506707006
# train loss:1.246470979668548
# =============== Final Test Accuracy ===============
# test acc:0.4819

# %% [markdown]
# ## overfit_weight_decay.py

# %%
# coding: utf-8
import os
import sys

sys.path.append(os.pardir)  # 为了导入父目录的文件而进行的设定
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 为了再现过拟合，减少学习数据
x_train = x_train[:300]
t_train = t_train[:300]

# weight decay（权值衰减）的设定 =======================
#weight_decay_lambda = 0 # 不使用权值衰减的情况
weight_decay_lambda = 0.1
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda)
optimizer = SGD(lr=0.01)

max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break


# 3.绘制图形==========
markers = {'train': 'o', 'test': 's'}
plt.figure(figsize=(12,10), dpi= 80)
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# epoch:0, train acc:0.11666666666666667, test acc:0.1029
# epoch:1, train acc:0.14333333333333334, test acc:0.1142
# epoch:2, train acc:0.20666666666666667, test acc:0.1456
# epoch:3, train acc:0.2633333333333333, test acc:0.1871
# epoch:4, train acc:0.2966666666666667, test acc:0.2384
# epoch:5, train acc:0.36666666666666664, test acc:0.2748
# epoch:6, train acc:0.3933333333333333, test acc:0.3184
# epoch:7, train acc:0.42333333333333334, test acc:0.3443
# epoch:8, train acc:0.42, test acc:0.3443
# epoch:9, train acc:0.43666666666666665, test acc:0.3498
# epoch:10, train acc:0.45, test acc:0.3766
# epoch:11, train acc:0.48, test acc:0.3949
# epoch:12, train acc:0.49, test acc:0.3991
# epoch:13, train acc:0.5133333333333333, test acc:0.4162
# epoch:14, train acc:0.54, test acc:0.4373
# epoch:15, train acc:0.5866666666666667, test acc:0.4583
# epoch:16, train acc:0.6, test acc:0.4778
# epoch:17, train acc:0.66, test acc:0.4984
# epoch:18, train acc:0.68, test acc:0.5227
# epoch:19, train acc:0.6633333333333333, test acc:0.5209
# epoch:20, train acc:0.6733333333333333, test acc:0.5343
# epoch:21, train acc:0.6866666666666666, test acc:0.5416
# epoch:22, train acc:0.69, test acc:0.5446
# epoch:23, train acc:0.6933333333333334, test acc:0.5441
# epoch:24, train acc:0.71, test acc:0.5629
# epoch:25, train acc:0.7233333333333334, test acc:0.5788
# epoch:26, train acc:0.7366666666666667, test acc:0.5846
# epoch:27, train acc:0.74, test acc:0.5854
# epoch:28, train acc:0.7366666666666667, test acc:0.5919
# epoch:29, train acc:0.7433333333333333, test acc:0.6071
# epoch:30, train acc:0.7633333333333333, test acc:0.6255
# epoch:31, train acc:0.7566666666666667, test acc:0.6209
# epoch:32, train acc:0.77, test acc:0.6196
# epoch:33, train acc:0.76, test acc:0.622
# epoch:34, train acc:0.77, test acc:0.6364
# epoch:35, train acc:0.8, test acc:0.6536
# epoch:36, train acc:0.8, test acc:0.662
# epoch:37, train acc:0.8133333333333334, test acc:0.6662
# epoch:38, train acc:0.83, test acc:0.6813
# epoch:39, train acc:0.83, test acc:0.6943
# epoch:40, train acc:0.8466666666666667, test acc:0.698
# epoch:41, train acc:0.8233333333333334, test acc:0.6829
# epoch:42, train acc:0.84, test acc:0.6914
# epoch:43, train acc:0.8533333333333334, test acc:0.7033
# epoch:44, train acc:0.8533333333333334, test acc:0.6975
# epoch:45, train acc:0.8466666666666667, test acc:0.7104
# epoch:46, train acc:0.8366666666666667, test acc:0.7107
# epoch:47, train acc:0.8666666666666667, test acc:0.7198
# epoch:48, train acc:0.86, test acc:0.7054
# epoch:49, train acc:0.8533333333333334, test acc:0.7038
# epoch:50, train acc:0.8633333333333333, test acc:0.7153
# epoch:51, train acc:0.8666666666666667, test acc:0.7166
# epoch:52, train acc:0.8733333333333333, test acc:0.725
# epoch:53, train acc:0.8666666666666667, test acc:0.7174
# epoch:54, train acc:0.87, test acc:0.7233
# epoch:55, train acc:0.8766666666666667, test acc:0.7257
# epoch:56, train acc:0.8733333333333333, test acc:0.7232
# epoch:57, train acc:0.8733333333333333, test acc:0.7231
# epoch:58, train acc:0.8833333333333333, test acc:0.7345
# epoch:59, train acc:0.8766666666666667, test acc:0.7292
# epoch:60, train acc:0.8633333333333333, test acc:0.7321
# epoch:61, train acc:0.89, test acc:0.7367
# epoch:62, train acc:0.89, test acc:0.7418
# epoch:63, train acc:0.8866666666666667, test acc:0.7492
# epoch:64, train acc:0.8933333333333333, test acc:0.7473
# epoch:65, train acc:0.9, test acc:0.7488
# epoch:66, train acc:0.8933333333333333, test acc:0.7522
# epoch:67, train acc:0.8966666666666666, test acc:0.7468
# epoch:68, train acc:0.8933333333333333, test acc:0.7414
# epoch:69, train acc:0.8933333333333333, test acc:0.748
# epoch:70, train acc:0.9, test acc:0.7589
# epoch:71, train acc:0.9033333333333333, test acc:0.754
# epoch:72, train acc:0.91, test acc:0.7577
# epoch:73, train acc:0.9, test acc:0.7553
# epoch:74, train acc:0.8966666666666666, test acc:0.7438
# epoch:75, train acc:0.9066666666666666, test acc:0.7522
# epoch:76, train acc:0.9, test acc:0.7591
# epoch:77, train acc:0.9033333333333333, test acc:0.7574
# epoch:78, train acc:0.91, test acc:0.7583
# epoch:79, train acc:0.8966666666666666, test acc:0.7589
# epoch:80, train acc:0.9133333333333333, test acc:0.7622
# epoch:81, train acc:0.9, test acc:0.7559
# epoch:82, train acc:0.8933333333333333, test acc:0.7445
# epoch:83, train acc:0.9, test acc:0.7389
# epoch:84, train acc:0.9066666666666666, test acc:0.7524
# epoch:85, train acc:0.9166666666666666, test acc:0.7658
# epoch:86, train acc:0.91, test acc:0.758
# epoch:87, train acc:0.92, test acc:0.7574
# epoch:88, train acc:0.9033333333333333, test acc:0.7546
# epoch:89, train acc:0.9, test acc:0.7496
# epoch:90, train acc:0.8933333333333333, test acc:0.753
# epoch:91, train acc:0.91, test acc:0.7661
# epoch:92, train acc:0.9166666666666666, test acc:0.766
# epoch:93, train acc:0.9066666666666666, test acc:0.7678
# epoch:94, train acc:0.91, test acc:0.7638
# epoch:95, train acc:0.92, test acc:0.7661
# epoch:96, train acc:0.9066666666666666, test acc:0.7656
# epoch:97, train acc:0.9266666666666666, test acc:0.7684
# epoch:98, train acc:0.9233333333333333, test acc:0.7653
# epoch:99, train acc:0.9166666666666666, test acc:0.7581
# epoch:100, train acc:0.92, test acc:0.7651
# epoch:101, train acc:0.9233333333333333, test acc:0.7677
# epoch:102, train acc:0.92, test acc:0.7606
# epoch:103, train acc:0.92, test acc:0.7636
# epoch:104, train acc:0.91, test acc:0.7624
# epoch:105, train acc:0.9033333333333333, test acc:0.7631
# epoch:106, train acc:0.9166666666666666, test acc:0.7624
# epoch:107, train acc:0.92, test acc:0.7649
# epoch:108, train acc:0.9166666666666666, test acc:0.7662
# epoch:109, train acc:0.91, test acc:0.7569
# epoch:110, train acc:0.9233333333333333, test acc:0.7641
# epoch:111, train acc:0.91, test acc:0.7529
# epoch:112, train acc:0.9166666666666666, test acc:0.766
# epoch:113, train acc:0.91, test acc:0.7636
# epoch:114, train acc:0.9133333333333333, test acc:0.7623
# epoch:115, train acc:0.9233333333333333, test acc:0.7646
# epoch:116, train acc:0.9266666666666666, test acc:0.7733
# epoch:117, train acc:0.93, test acc:0.7699
# epoch:118, train acc:0.9233333333333333, test acc:0.7601
# epoch:119, train acc:0.9233333333333333, test acc:0.7686
# epoch:120, train acc:0.93, test acc:0.7674
# epoch:121, train acc:0.9166666666666666, test acc:0.7626
# epoch:122, train acc:0.9166666666666666, test acc:0.7625
# epoch:123, train acc:0.91, test acc:0.7609
# epoch:124, train acc:0.9366666666666666, test acc:0.7712
# epoch:125, train acc:0.9333333333333333, test acc:0.7705
# epoch:126, train acc:0.9333333333333333, test acc:0.767
# epoch:127, train acc:0.94, test acc:0.7684
# epoch:128, train acc:0.9266666666666666, test acc:0.7601
# epoch:129, train acc:0.92, test acc:0.7653
# epoch:130, train acc:0.91, test acc:0.7543
# epoch:131, train acc:0.9266666666666666, test acc:0.7591
# epoch:132, train acc:0.92, test acc:0.7637
# epoch:133, train acc:0.93, test acc:0.7694
# epoch:134, train acc:0.9266666666666666, test acc:0.7692
# epoch:135, train acc:0.9366666666666666, test acc:0.7693
# epoch:136, train acc:0.92, test acc:0.7642
# epoch:137, train acc:0.9266666666666666, test acc:0.7601
# epoch:138, train acc:0.93, test acc:0.7654
# epoch:139, train acc:0.9266666666666666, test acc:0.7641
# epoch:140, train acc:0.9266666666666666, test acc:0.77
# epoch:141, train acc:0.9333333333333333, test acc:0.7716
# epoch:142, train acc:0.93, test acc:0.7742
# epoch:143, train acc:0.9333333333333333, test acc:0.7688
# epoch:144, train acc:0.93, test acc:0.7684
# epoch:145, train acc:0.9366666666666666, test acc:0.7682
# epoch:146, train acc:0.9366666666666666, test acc:0.775
# epoch:147, train acc:0.93, test acc:0.7714
# epoch:148, train acc:0.93, test acc:0.773
# epoch:149, train acc:0.93, test acc:0.7673
# epoch:150, train acc:0.9233333333333333, test acc:0.7651
# epoch:151, train acc:0.9233333333333333, test acc:0.7643
# epoch:152, train acc:0.93, test acc:0.7682
# epoch:153, train acc:0.92, test acc:0.7643
# epoch:154, train acc:0.93, test acc:0.7731
# epoch:155, train acc:0.93, test acc:0.7705
# epoch:156, train acc:0.91, test acc:0.7582
# epoch:157, train acc:0.9433333333333334, test acc:0.7711
# epoch:158, train acc:0.93, test acc:0.7711
# epoch:159, train acc:0.9366666666666666, test acc:0.7701
# epoch:160, train acc:0.93, test acc:0.765
# epoch:161, train acc:0.9433333333333334, test acc:0.772
# epoch:162, train acc:0.9233333333333333, test acc:0.765
# epoch:163, train acc:0.9366666666666666, test acc:0.7671
# epoch:164, train acc:0.9333333333333333, test acc:0.7628
# epoch:165, train acc:0.94, test acc:0.7699
# epoch:166, train acc:0.9166666666666666, test acc:0.7619
# epoch:167, train acc:0.91, test acc:0.7577
# epoch:168, train acc:0.93, test acc:0.7684
# epoch:169, train acc:0.9166666666666666, test acc:0.7602
# epoch:170, train acc:0.9233333333333333, test acc:0.767
# epoch:171, train acc:0.92, test acc:0.7683
# epoch:172, train acc:0.9133333333333333, test acc:0.7593
# epoch:173, train acc:0.9266666666666666, test acc:0.7667
# epoch:174, train acc:0.93, test acc:0.7651
# epoch:175, train acc:0.9366666666666666, test acc:0.7695
# epoch:176, train acc:0.9366666666666666, test acc:0.7657
# epoch:177, train acc:0.93, test acc:0.7705
# epoch:178, train acc:0.94, test acc:0.7724
# epoch:179, train acc:0.92, test acc:0.7672
# epoch:180, train acc:0.9266666666666666, test acc:0.7631
# epoch:181, train acc:0.91, test acc:0.7538
# epoch:182, train acc:0.9266666666666666, test acc:0.7653
# epoch:183, train acc:0.9333333333333333, test acc:0.7707
# epoch:184, train acc:0.9266666666666666, test acc:0.7628
# epoch:185, train acc:0.9233333333333333, test acc:0.7573
# epoch:186, train acc:0.9366666666666666, test acc:0.7623
# epoch:187, train acc:0.9266666666666666, test acc:0.7578
# epoch:188, train acc:0.9333333333333333, test acc:0.7588
# epoch:189, train acc:0.9366666666666666, test acc:0.7672
# epoch:190, train acc:0.94, test acc:0.7586
# epoch:191, train acc:0.9166666666666666, test acc:0.7584
# epoch:192, train acc:0.93, test acc:0.769
# epoch:193, train acc:0.9266666666666666, test acc:0.7635
# epoch:194, train acc:0.9433333333333334, test acc:0.7712
# epoch:195, train acc:0.9233333333333333, test acc:0.7651
# epoch:196, train acc:0.9366666666666666, test acc:0.7632
# epoch:197, train acc:0.92, test acc:0.7582
# epoch:198, train acc:0.9233333333333333, test acc:0.7599
# epoch:199, train acc:0.9133333333333333, test acc:0.7571
# epoch:200, train acc:0.91, test acc:0.7559

# %% [markdown]
# ## weight_init_activation_histogram.py

# %%
# coding: utf-8
import numpy as np
import matplotlib.pyplot as plt


def sigmoid(x):
    return 1 / (1 + np.exp(-x))


def ReLU(x):
    return np.maximum(0, x)


def tanh(x):
    return np.tanh(x)
    
input_data = np.random.randn(1000, 100)  # 1000个数据
node_num = 100  # 各隐藏层的节点（神经元）数
hidden_layer_size = 5  # 隐藏层有5层
activations = {}  # 激活值的结果保存在这里

x = input_data

for i in range(hidden_layer_size):
    if i != 0:
        x = activations[i-1]

    # 改变初始值进行实验！
    w = np.random.randn(node_num, node_num) * 1
    # w = np.random.randn(node_num, node_num) * 0.01
    # w = np.random.randn(node_num, node_num) * np.sqrt(1.0 / node_num)
    # w = np.random.randn(node_num, node_num) * np.sqrt(2.0 / node_num)


    a = np.dot(x, w)


    # 将激活函数的种类也改变，来进行实验！
    z = sigmoid(a)
    # z = ReLU(a)
    # z = tanh(a)

    activations[i] = z

# 绘制直方图
plt.figure(figsize=(12,10), dpi= 80)
for i, a in activations.items():
    plt.subplot(1, len(activations), i+1)
    plt.title(str(i+1) + "-layer")
    if i != 0: plt.yticks([], [])
    # plt.xlim(0.1, 1)
    # plt.ylim(0, 7000)
    plt.hist(a.flatten(), 30, range=(0,1))
plt.show()

# %% [markdown]
# ## weight_init_compare.py

# %%
# coding: utf-8
import os
import sys

sys.path.append(os.pardir)  # 为了导入父目录的文件而进行的设定
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.util import smooth_curve
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD


# 0:读入MNIST数据==========
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

train_size = x_train.shape[0]
batch_size = 128
max_iterations = 2000


# 1:进行实验的设置==========
weight_init_types = {'std=0.01': 0.01, 'Xavier': 'sigmoid', 'He': 'relu'}
optimizer = SGD(lr=0.01)

networks = {}
train_loss = {}
for key, weight_type in weight_init_types.items():
    networks[key] = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100],
                                  output_size=10, weight_init_std=weight_type)
    train_loss[key] = []


# 2:开始训练==========
for i in range(max_iterations):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]
    
    for key in weight_init_types.keys():
        grads = networks[key].gradient(x_batch, t_batch)
        optimizer.update(networks[key].params, grads)
    
        loss = networks[key].loss(x_batch, t_batch)
        train_loss[key].append(loss)
    
    if i % 100 == 0:
        print("===========" + "iteration:" + str(i) + "===========")
        for key in weight_init_types.keys():
            loss = networks[key].loss(x_batch, t_batch)
            print(key + ":" + str(loss))


# 3.绘制图形==========
markers = {'std=0.01': 'o', 'Xavier': 's', 'He': 'D'}
x = np.arange(max_iterations)
plt.figure(figsize=(12,10), dpi= 80)
for key in weight_init_types.keys():
    plt.plot(x, smooth_curve(train_loss[key]), marker=markers[key], markevery=100, label=key)
plt.xlabel("iterations")
plt.ylabel("loss")
plt.ylim(0, 2.5)
plt.legend()
plt.show()
# Out:
# ===========iteration:0===========
# std=0.01:2.302507869540855
# Xavier:2.30766619458611
# He:2.3384608723875013
# ===========iteration:100===========
# std=0.01:2.302568197316708
# Xavier:2.214510770308385
# He:1.4953733502037472
# ===========iteration:200===========
# std=0.01:2.3012591713257926
# Xavier:2.112461377668698
# He:0.7676511422873337
# ===========iteration:300===========
# std=0.01:2.3001756431175235
# Xavier:1.8271016016260027
# He:0.572104004154788
# ===========iteration:400===========
# std=0.01:2.302784737822709
# Xavier:1.2012002101358452
# He:0.38208123951303313
# ===========iteration:500===========
# std=0.01:2.30248103227263
# Xavier:0.8339566028402512
# He:0.35834774420550475
# ===========iteration:600===========
# std=0.01:2.2959797081338182
# Xavier:0.6534987869343819
# He:0.4029810782578087
# ===========iteration:700===========
# std=0.01:2.3036008692402117
# Xavier:0.46340004635716736
# He:0.23026754841206293
# ===========iteration:800===========
# std=0.01:2.300112890956155
# Xavier:0.4658296286762486
# He:0.30911102907543736
# ===========iteration:900===========
# std=0.01:2.2953874279751383
# Xavier:0.43578130332558807
# He:0.35704961675589664
# ===========iteration:1000===========
# std=0.01:2.2917534699337505
# Xavier:0.3572422839683278
# He:0.22472425544427213
# ===========iteration:1100===========
# std=0.01:2.302593606804707
# Xavier:0.3890841098511243
# He:0.23437196937437715
# ===========iteration:1200===========
# std=0.01:2.3013809999286403
# Xavier:0.35817025370612326
# He:0.22195935386019566
# ===========iteration:1300===========
# std=0.01:2.30486406803851
# Xavier:0.42510103462809196
# He:0.24431748960571836
# ===========iteration:1400===========
# std=0.01:2.298817497082627
# Xavier:0.3938263643173524
# He:0.2614096229778104
# ===========iteration:1500===========
# std=0.01:2.3031052692411382
# Xavier:0.34559634471869854
# He:0.2511238606327558
# ===========iteration:1600===========
# std=0.01:2.303686134802354
# Xavier:0.2703217836726867
# He:0.1833451440725814
# ===========iteration:1700===========
# std=0.01:2.296836233086446
# Xavier:0.3386042337728202
# He:0.25398875440592594
# ===========iteration:1800===========
# std=0.01:2.3038812504900408
# Xavier:0.17271084594721411
# He:0.12174529618381935
# ===========iteration:1900===========
# std=0.01:2.303087439602273
# Xavier:0.30811838503113076
# He:0.1868670352019639
